# %%
import requests
import pandas as pd
from Postgres_Controller import PostgresConnection

# %%
server_name = 'http://77.83.99.86:3030'
service_name = 'ds'
fuseki_url = server_name + '/' + service_name

# %%
URI_prefix = 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#'

def fuseki_to_df(response):
    headers = response.json()["head"]["vars"]
    results = response.json()["results"]['bindings']

    if not results:
        return []

    rows = []

    for result in results:
        result_dict = {}
        for header in headers:
            if header not in result:
                result_dict[header] = None
            else:
                value = result[header]['value']

                if URI_prefix in value:
                    value = value.split('#')[-1]
                result_dict[header] = value

        rows.append(result_dict)

    df = pd.DataFrame(rows)

    return df

# %%
query = '''
PREFIX a: <http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT
    # ?projectId
    # ?projectTitle
    # ?specie
    (COUNT(*) AS ?specimens)
    (MIN(?minAge) as ?min_age)
    (MAX(?maxAge) as ?max_age)
    # ?ageUnit
WHERE {
    # ?project rdf:type a:Project ;
             a:PR.hasProjectID ?projectId ;
              a:SPR.hasProjectTitle ?projectTitle .
    # ?specimen rdf:type a:Specimen ;
              a:SPR.hasProjectTitle ?projectTitle ;
              a:SPR.hasMinAge ?minAge ;
              a:SPR.hasMaxAge ?maxAge ;
              a:SPR.hasSpecie ?specie ;
              a:SPR.hasAgeUnit ?ageUnit .
}
GROUP BY 
    # ?projectId
    # ?projectTitle
    # ?specie
    # ?ageUnit
ORDER BY ?projectTitle
'''

# %%
response = requests.post(fuseki_url, data={'query': query})

# %%
response.json()
# Out:
# {'head': {'vars': ['projectId',
#    'projectTitle',
#    'specie',
#    'specimens',
#    'min_age',
#    'max_age',
#    'ageUnit']},
#  'results': {'bindings': [{'projectId': {'type': 'literal',
#      'value': '74b6d569-3b11-42ef-b6b1-a0454522b4a0'},
#     'projectTitle': {'type': 'literal',
#      'value': '1.3 Million Brain Cells from E18 Mice'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '18'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '18'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal',
#      'value': 'f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A Single-Cell Transcriptomic Map of the Human and Mouse Pancreas Reveals Inter- and Intra-cell Population Structure'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '17'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '59'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-141273'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A single cell transcriptome atlas of myeloid blood cell lineages in Drosophila [scRNA-seq]'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#DrosophilaMelanogaster'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '72'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '120'},
#     'ageUnit': {'type': 'literal', 'value': 'hour'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-150728'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A single-cell atlas of the peripheral immune response to severe COVID-19'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '69'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': '1defdada-a365-44ad-9b29-443b06bd11d6'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A single-cell molecular map of mouse gastrulation and early organogenesis'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '26'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': '4a95101c-9ffc-4f30-a809-f04518a23803'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A single-cell reference map of transcriptional states for human blood and tissue T cell activation'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '16'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '50'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '65'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': '8185730f-4113-40d3-9cc3-929271784c2b'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A single-cell transcriptome atlas of the adult human retina'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '42'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '80'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-98556'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A versatile approach for assessing human stem cell-derived retinal progeny using single cell transcriptomics'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'notApplicable'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-98556'},
#     'projectTitle': {'type': 'literal',
#      'value': 'A versatile approach for assessing human stem cell-derived retinal progeny using single cell transcriptomics'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '64'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '64'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6308'},
#     'projectTitle': {'type': 'literal',
#      'value': 'An integrated approach to profile lung tumor endothelial cell heterogeneity across species and models and to identify angiogenic candidates'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '17'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '57'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '74'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': '005d611a-14d5-4fbf-846e-571a1f874f70'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Assessing the relevance of organoids to model inter-individual variation'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '40'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '69'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': 'a29952d9-925e-40f4-8a1c-274f118f1f51'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Bone marrow plasma cells from hip replacement surgeries'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '49'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '85'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': 'cc95ff89-2e68-4a08-a234-480eca21ce79'},
#     'projectTitle': {'type': 'literal', 'value': 'Census of Immune Cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '127'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '0'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '52'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6077'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Determining single-cell mRNA expression profiles of a specific population isolated from zebrafish embryos at 10 hours post fertilization'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#DanioRerio'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'ageUnit': {'type': 'literal', 'value': 'hour'}},
#    {'projectId': {'type': 'literal',
#      'value': '4d6f6c96-2a83-43d8-8fe1-0f53bffd4674'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Dissecting the human liver cellular landscape by single cell RNA-seq reveals novel intrahepatic monocyte/ macrophage populations'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '65'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7142'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Drop-seq analysis of bleomycin-treated and control mouse lung single-cell suspensions'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-56'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Drop-seq single-cell sequencing of hemocytes from Drosophila larvae after wasp infestation'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#DrosophilaMelanogaster'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '96'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '128'},
#     'ageUnit': {'type': 'literal', 'value': 'hour'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-121619'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Dynamics of gene expression in single root cells of Arabidopsis thaliana'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#ArabidopsisThaliana'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7703'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Fibroblastic reticular cells in the spleen - total splenic Stroma cells - single cell RNAseq dataset 2'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-5'},
#     'projectTitle': {'type': 'literal',
#      'value': 'High-throughput single cell transcriptome profiling of plant tissue: single cell dataset '},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#ArabidopsisThaliana'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-4'},
#     'projectTitle': {'type': 'literal',
#      'value': 'High-throughput single-cell transcriptome profiling of plant cell types - single cell dataset'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#ArabidopsisThaliana'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-75140'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Human cerebral organoids recapitulate gene expression programs of fetal neocortex development'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'notApplicable'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-75140'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Human cerebral organoids recapitulate gene expression programs of fetal neocortex development'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '13'},
#     'ageUnit': {'type': 'literal', 'value': 'gestationalWeek'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-75140'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Human cerebral organoids recapitulate gene expression programs of fetal neocortex development'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '36'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '36'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7407'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Human fetal liver, skin and kidney single cell transcriptome data'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '27'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '17'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-139324'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Immune landscape of viral- and carcinogen-derived head and neck cancer'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '63'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '28'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '80'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-149689'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Immunophenotyping of COVID-19 and Influenza Underscores the Association of Type I IFN Response in Severe COVID-19'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '38'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '82'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6487'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Interferon gene therapy reprograms the leukemia microenvironment inducing protective immunity to multiple tumor antigens'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': 'c4077b3c-5c98-4d26-a614-246d12c2e5d7'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Ischaemic sensitivity of human tissue by single cell RNA seq'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '147'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '75'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-130148'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Lung Cell Atlas: Single cell RNA sequencing analysis of fresh resected human lung tissue - Drop-seq dataset'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '58'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '69'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': '8c3c290d-dfff-4553-8868-54ce45f4ba7f'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Melanoma infiltration of stromal and immune cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '54'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-ENAD-30'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Molecular Mechanisms Driving Switch Behavior in Xylem Cell Differentiation'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#ArabidopsisThaliana'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-9'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Multi-modal analysis of the aging mouse lung at cellular resolution'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '24'},
#     'ageUnit': {'type': 'literal', 'value': 'month'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-124263'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Neonatal and adult human testis defined at the single-cell level'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-124263'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Neonatal and adult human testis defined at the single-cell level'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '37'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '42'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7094'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Origin and differentiation trajectories of fibroblastic reticular cells in the splenic white pulp - single cell RNAseq dataset 1'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': '90bd6933-40c0-48d4-8d76-778c103bf545'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Precursors of human CD4+ cytotoxic T lymphocytes identified by single-cell transcriptome analysis'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '28'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '18'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '60'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': '091cf39b-01bc-42e5-9437-f419a66c8a45'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Profiling of CD34+ cells from human bone marrow to understand hematopoiesis'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '19'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '35'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-9221'},
#     'projectTitle': {'type': 'literal',
#      'value': 'RNA-seq of RBC depleted whole blood from COVID-19 patients and controls'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'notAvailable'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-9221'},
#     'projectTitle': {'type': 'literal',
#      'value': 'RNA-seq of RBC depleted whole blood from COVID-19 patients and controls'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '69'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-4888'},
#     'projectTitle': {'type': 'literal',
#      'value': 'RNA-seq of coding RNA from single cells to assess the impact of aging on cell-to-cell transcriptional variability during immune stimulation'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '42'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'ageUnit': {'type': 'literal', 'value': 'month'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6385'},
#     'projectTitle': {'type': 'literal',
#      'value': 'RNA-sequencing for functional prediction of RNAs'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-7'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single Cell RNA sequencing of Adult Human Breast Epithelial Cells - individuals 1-3'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '37'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-146122'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single Cell RNA-sequencing of murine tail interfollicular epidermis basal cells at postnatal days 7, 30 and in adult'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '68'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal',
#      'value': '027c51c6-0719-469f-a7f5-640fe57cbece'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single Cell Transcriptomics of a Human Kidney Allograft Biopsy Defines a Diverse Inflammatory Response'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-94641'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA expression of mouse embryonic basal forebrain'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'embryonicDay'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-8698'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA on hemocytes from wandering larvae of Drosophila melanogaster not infested and infested by Leptopilina boulardi'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#DrosophilaMelanogaster'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '115'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '115'},
#     'ageUnit': {'type': 'literal', 'value': 'hour'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7606'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA seq of influenza tetramer specific CD8+ T cells from baseline, acute and long term memory timepoints'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '31'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '31'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-81682'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA sequencing of mouse hematopoietic stem and progenitor cells '},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-8810'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-Seq of the mouse heart in response to chronic stress'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6173'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-Seq of the murine non-myocyte cardiac cellulome'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-124472'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-Seq profiling of human embryonic kidney outer and inner cortical cells and kidney organoid cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'notApplicable'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-124472'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-Seq profiling of human embryonic kidney outer and inner cortical cells and kidney organoid cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '15'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '17'},
#     'ageUnit': {'type': 'literal', 'value': 'gestationalWeek'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-8559'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq from 10X for a living biobank of ovarian cancer ex vivo models reveals profound mitotic heterogeneity'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '46'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '81'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-ENAD-18'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of Schistosoma mansoni stem cells from in vitro-transformed mother sporocysts'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#SchistosomaMansoni'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '48'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '48'},
#     'ageUnit': {'type': 'literal', 'value': 'hour'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6879'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of Stmn1+ isthmal cells and Pgc+ chief cells to compare and characterize distinct gastric corpus stem cells at molecular level'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7249'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of a human ex vivo ovarian model with matched stromal cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '81'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '81'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-76312'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of cancer stem cells from patients with chronic myeloid leukemia during the disease course'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '26'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '20'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '74'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-76312'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of cancer stem cells from patients with chronic myeloid leukemia during the disease course'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'notAvailable'}},
#    {'projectId': {'type': 'literal', 'value': 'E-ENAD-17'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of glioblastoma cells from five primary tumors'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '5'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '55'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '70'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-99795'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of human LNCaP prostate carcinoma cells cultured in the absence and presence of androgen for 12 hours'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '50'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '50'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-81608'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of human islet cells from non diabetic and type II diabetes organ donors'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '18'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '23'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '68'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-83139'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single cell RNA-seq of human pancreatic endocrine cells from Juvenile, adult control and type 2 diabetic donors'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '19'},
#     'max_age': {'type': 'literal',
# ...
#      'value': 'Single-cell transcriptional analysis reveals innate lymphoid cell (ILC)-like cells in zebrafish'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#DanioRerio'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '11'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'ageUnit': {'type': 'literal', 'value': 'month'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-125970'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single-cell transcriptome analysis reveals differential nutrient absorption functions in human intestine'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '49'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '67'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-10'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single-cell transcriptome profiling for metastatic renal cell carcinoma patient-derived cells and xenografts'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '43'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '43'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-135922'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Single-cell transcriptomics of the human retinal pigment epithelium and choroid in health and macular degeneration'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '54'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '92'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': 'abe1a013-af7a-45ed-8c26-f3793c24a1f4'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Spatio-temporal immune zonation of the human kidney'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '16'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': 'abe1a013-af7a-45ed-8c26-f3793c24a1f4'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Spatio-temporal immune zonation of the human kidney'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '53'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '72'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': 'f8aa201c-4ff1-45a4-890e-840d63459ca2'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Structural Remodeling of the Human Colonic Mesenchyme in Inflammatory Bowel Disease'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '13'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '29'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '69'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal',
#      'value': 'f8aa201c-4ff1-45a4-890e-840d63459ca2'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Structural Remodeling of the Human Colonic Mesenchyme in Inflammatory Bowel Disease'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': '88ec040b-8705-4f77-8f41-f81e57632f7d'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Systematic comparative analysis of single cell RNA-sequencing methods'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'ageUnit': {'type': 'literal', 'value': 'month'}},
#    {'projectId': {'type': 'literal',
#      'value': 'e0009214-c0a0-4a7b-96e2-d6a83e966ce0'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Tabula Muris: Transcriptomic characterization of 20 organs and tissues from Mus musculus at single cell resolution'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '222'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'ageUnit': {'type': 'literal', 'value': 'month'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-21'},
#     'projectTitle': {'type': 'literal',
#      'value': 'The Drosophila Embryo at Single-Cell Transcriptome Resolution - Drosophila melanogaster dataset'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#DrosophilaMelanogaster'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'ageUnit': {'type': 'literal', 'value': 'hour'}},
#    {'projectId': {'type': 'literal', 'value': 'E-GEOD-134144'},
#     'projectTitle': {'type': 'literal',
#      'value': 'The Dynamic Transcriptional Cell Atlas of Testis Development during Human Puberty'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '60'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-4547'},
#     'projectTitle': {'type': 'literal',
#      'value': 'The Global Molecular Landscape of dormant Hematopoietic Stem Cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '29'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '33'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': '4e6f083b-5b9a-4393-9890-2a83da8188f1'},
#     'projectTitle': {'type': 'literal',
#      'value': 'The emergent landscape of the mouse gut endoderm at single-cell resolution'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '6'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal',
#      'value': '9c20a245-f2c0-43ae-82c9-2232ec6b594f'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Transcriptomic classification of human retinal cell types with single-nuclei RNA-seq.'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '7'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '73'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '84'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-4850'},
#     'projectTitle': {'type': 'literal',
#      'value': 'Transcriptomic profiling of antigen-specific T cells at the single-cell level after clearance of hepatitis C virus'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '42'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '42'},
#     'ageUnit': {'type': 'literal', 'value': 'year'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-7678'},
#     'projectTitle': {'type': 'literal',
#      'value': 'scRNA-seq analysis of lung CD64-expressing mononuclear cells, patrolling and classical monocytes from steady-state C57BL/6J mice'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '29'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-CURD-57'},
#     'projectTitle': {'type': 'literal',
#      'value': 'scRNA-seq of Anopheles gambiae hemocytes after blood-feeding, Plasmodium berghei infection, or sugar feeding'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#AnophelesGambiae'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '4'},
#     'ageUnit': {'type': 'literal', 'value': 'day'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-6677'},
#     'projectTitle': {'type': 'literal',
#      'value': 'scRNA-seq of Mus musculus subcutaneous Lin- cells derived from the subcutaneous adipose stromal vascular fraction'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-8221'},
#     'projectTitle': {'type': 'literal',
#      'value': 'scRNA-seq of human fetal lung primary tissues and cell cultures derived from fetal bud tip progenitors under dual SMAD treatment'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#HomoSapiens'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '-1'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '21'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}},
#    {'projectId': {'type': 'literal', 'value': 'E-MTAB-5802'},
#     'projectTitle': {'type': 'literal',
#      'value': 'scRNA-seq of mouse adipose stem and progenitor cells'},
#     'specie': {'type': 'uri',
#      'value': 'http://www.semanticweb.org/alicia/ontologies/2020/8/singleCellRepositories#MusMusculus'},
#     'specimens': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'min_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
#     'max_age': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'ageUnit': {'type': 'literal', 'value': 'week'}}]}}

# %%
specimens = fuseki_to_df(response)
specimens
# Out:
#                                 projectId  \
# 0    74b6d569-3b11-42ef-b6b1-a0454522b4a0
# 1    f86f1ab4-1fbb-4510-ae35-3ffd752d4dfc
# 2                           E-GEOD-141273
# 3                           E-GEOD-150728
# 4    1defdada-a365-44ad-9b29-443b06bd11d6
# ..                                    ...
# 139                           E-MTAB-7678
# 140                             E-CURD-57
# 141                           E-MTAB-6677
# 142                           E-MTAB-8221
# 143                           E-MTAB-5802
#
#                                           projectTitle  \
# 0                1.3 Million Brain Cells from E18 Mice
# 1    A Single-Cell Transcriptomic Map of the Human ...
# 2    A single cell transcriptome atlas of myeloid b...
# 3    A single-cell atlas of the peripheral immune r...
# 4    A single-cell molecular map of mouse gastrulat...
# ..                                                 ...
# 139  scRNA-seq analysis of lung CD64-expressing mon...
# 140  scRNA-seq of Anopheles gambiae hemocytes after...
# 141  scRNA-seq of Mus musculus subcutaneous Lin- ce...
# 142  scRNA-seq of human fetal lung primary tissues ...
# 143  scRNA-seq of mouse adipose stem and progenitor...
#
#                      specie specimens min_age max_age ageUnit
# 0               MusMusculus         2      18      18     day
# 1               HomoSapiens         4      17      59    year
# 2    DrosophilaMelanogaster         4      72     120    hour
# 3               HomoSapiens        12      20      69    year
# 4               MusMusculus        26       7       9    week
# ..                      ...       ...     ...     ...     ...
# 139             MusMusculus         1      10      29    week
# 140        AnophelesGambiae         3       4       4     day
# 141             MusMusculus         1       8       8    week
# 142             HomoSapiens         9      -1      21    week
# 143             MusMusculus         3       8      10    week
#
# [144 rows x 7 columns]

# %%
query = '''
    SELECT DISTINCT project_id FROM percentil_groups;
'''

# %%
with PostgresConnection() as conn:
    cur = conn.cursor()

    print("Querying number of percentiles")
    cur.execute(query)
    project_ids = cur.fetchall()
    
    # close communication with the PostgreSQL database server
    cur.close()
    
    project_ids = [project_id[0] for project_id in project_ids]
    print(project_ids)
# Out:
# Querying number of percentiles
# ['E-MTAB-7703', 'E-MTAB-7381', 'E-GEOD-81383', 'E-GEOD-149689', 'E-MTAB-6818', 'E-GEOD-109159', 'E-MTAB-7901', 'E-GEOD-99795', 'E-ENAD-16', 'E-GEOD-36552', 'E-GEOD-100058', 'E-GEOD-139324', 'E-GEOD-100426', 'E-CURD-13', 'E-GEOD-124472', 'E-GEOD-111727', 'E-GEOD-100618', 'E-MTAB-7660', 'E-MTAB-6653', 'E-CURD-3', 'E-GEOD-90848', 'E-GEOD-75367', '116965f3-f094-4769-9d28-ae675c1b569c', 'E-MTAB-7142', 'E-GEOD-146122', 'E-MTAB-6505', 'E-GEOD-124263', 'E-ENAD-21', 'E-MTAB-7678', 'E-MTAB-8077', 'E-GEOD-86618', 'E-ENAD-19', 'E-MTAB-6946', 'E-GEOD-99058', 'E-MTAB-7324', 'E-GEOD-99235', 'E-GEOD-109979', 'E-MTAB-7094', 'E-MTAB-7311', 'E-GEOD-98556', 'E-GEOD-125970', 'E-CURD-21', 'E-MTAB-6362', 'E-GEOD-71585', 'E-MTAB-6819', 'E-GEOD-137537', 'E-MTAB-7407', 'E-MTAB-6677', 'E-GEOD-135922', 'E-MTAB-7325', 'E-ENAD-18', 'E-MTAB-6976', 'E-MTAB-5530', 'E-MTAB-6308', 'E-MTAB-7427', 'E-MTAB-6945', 'E-GEOD-81608', 'E-MTAB-7376', 'E-GEOD-130473', 'E-MTAB-5485', '4d6f6c96-2a83-43d8-8fe1-0f53bffd4674', 'E-GEOD-123013', 'E-GEOD-109796', 'E-CURD-57', 'E-GEOD-150728', 'E-MTAB-6386', 'E-MTAB-6077', 'E-GEOD-81682', 'f8aa201c-4ff1-45a4-890e-840d63459ca2', 'E-MTAB-8810', 'E-MTAB-7195', 'E-MTAB-7052', 'E-GEOD-103011', 'E-GEOD-70580', 'E-ENAD-30', 'E-CURD-12', 'E-MTAB-8221', 'E-MTAB-5802', 'E-CURD-5', 'E-MTAB-7303', 'E-MTAB-7320', 'E-MTAB-7051', 'E-ENAD-20', 'E-CURD-4', 'ae71be1d-ddd8-4feb-9bed-24c3ddb6e1ad', 'E-MTAB-6108', '4a95101c-9ffc-4f30-a809-f04518a23803', 'E-GEOD-76312', 'E-MTAB-6385', 'E-MTAB-7249', 'E-ENAD-27', 'E-MTAB-7159', 'E-MTAB-6379', 'E-MTAB-7149', 'E-MTAB-6524', 'E-MTAB-7365', 'E-GEOD-141273', 'E-MTAB-7078', 'E-CURD-7', 'E-CURD-6', 'E-CURD-11', 'E-GEOD-102475', 'E-ENAD-13', 'E-MTAB-7037', 'E-MTAB-6911', 'E-GEOD-110499', 'E-GEOD-134144', 'E-GEOD-114530', 'E-MTAB-6173', 'E-CURD-2', 'E-MTAB-6142', 'E-MTAB-6925', 'E-GEOD-89910', 'E-GEOD-84465', 'E-GEOD-121619', 'E-GEOD-124858', 'E-GEOD-77944', 'E-CURD-55', 'E-MTAB-7417', 'E-MTAB-5553', 'E-MTAB-7008', 'E-MTAB-9221', 'E-GEOD-94641', 'E-MTAB-4617', 'E-CURD-52', '2043c65a-1cf8-4828-a656-9e247d4e64f1', 'E-CURD-56', 'E-MTAB-8410', 'E-GEOD-100911', 'E-MTAB-7606', 'E-MTAB-6912', '8c3c290d-dfff-4553-8868-54ce45f4ba7f', 'E-MTAB-8559', 'E-MTAB-8483', 'E-GEOD-83139', 'E-GEOD-87631', 'E-CURD-10', 'E-ENAD-17', 'E-MTAB-6987', 'E-GEOD-108221', 'E-ENAD-14', 'E-CURD-46', 'E-MTAB-6487', 'abe1a013-af7a-45ed-8c26-f3793c24a1f4', 'E-GEOD-103334', 'E-MTAB-4888', 'E-GEOD-75140', 'E-MTAB-6051', 'E-MTAB-6970', 'E-MTAB-2983', 'E-GEOD-130148', 'E-MTAB-7117', 'E-CURD-9', 'E-GEOD-106973', 'E-GEOD-98816', 'E-GEOD-89232', 'E-MTAB-6879', 'E-MTAB-6058', 'E-MTAB-5661', 'E-MTAB-7098', 'E-CURD-53', 'E-MTAB-8698', 'E-MTAB-5727', 'E-GEOD-75688', 'E-MTAB-7194', 'E-MTAB-4547', 'E-MTAB-4850', 'cc95ff89-2e68-4a08-a234-480eca21ce79', '091cf39b-01bc-42e5-9437-f419a66c8a45']

# %%
specimens = specimens[specimens['projectId'].isin(project_ids)]
specimens
# Out:
#                                 projectId  \
# 2                           E-GEOD-141273
# 3                           E-GEOD-150728
# 5    4a95101c-9ffc-4f30-a809-f04518a23803
# 7                            E-GEOD-98556
# 8                            E-GEOD-98556
# ..                                    ...
# 139                           E-MTAB-7678
# 140                             E-CURD-57
# 141                           E-MTAB-6677
# 142                           E-MTAB-8221
# 143                           E-MTAB-5802
#
#                                           projectTitle  \
# 2    A single cell transcriptome atlas of myeloid b...
# 3    A single-cell atlas of the peripheral immune r...
# 5    A single-cell reference map of transcriptional...
# 7    A versatile approach for assessing human stem ...
# 8    A versatile approach for assessing human stem ...
# ..                                                 ...
# 139  scRNA-seq analysis of lung CD64-expressing mon...
# 140  scRNA-seq of Anopheles gambiae hemocytes after...
# 141  scRNA-seq of Mus musculus subcutaneous Lin- ce...
# 142  scRNA-seq of human fetal lung primary tissues ...
# 143  scRNA-seq of mouse adipose stem and progenitor...
#
#                      specie specimens min_age max_age        ageUnit
# 2    DrosophilaMelanogaster         4      72     120           hour
# 3               HomoSapiens        12      20      69           year
# 5               HomoSapiens        16      50      65           year
# 7               HomoSapiens         1      -1      -1  notApplicable
# 8               HomoSapiens         1      64      64           year
# ..                      ...       ...     ...     ...            ...
# 139             MusMusculus         1      10      29           week
# 140        AnophelesGambiae         3       4       4            day
# 141             MusMusculus         1       8       8           week
# 142             HomoSapiens         9      -1      21           week
# 143             MusMusculus         3       8      10           week
#
# [129 rows x 7 columns]

# %%
specimens['ageUnit'].unique()
# Out:
# array(['hour', 'year', 'notApplicable', 'week', 'day', 'gestationalWeek',
#        'month', 'notAvailable', 'embryonicDay'], dtype=object)

# %%
specimens = specimens[~specimens['ageUnit'].isin(['notApplicable', 'notAvailable'])]
specimens
# Out:
#                                 projectId  \
# 2                           E-GEOD-141273
# 3                           E-GEOD-150728
# 5    4a95101c-9ffc-4f30-a809-f04518a23803
# 8                            E-GEOD-98556
# 9                             E-MTAB-6308
# ..                                    ...
# 139                           E-MTAB-7678
# 140                             E-CURD-57
# 141                           E-MTAB-6677
# 142                           E-MTAB-8221
# 143                           E-MTAB-5802
#
#                                           projectTitle  \
# 2    A single cell transcriptome atlas of myeloid b...
# 3    A single-cell atlas of the peripheral immune r...
# 5    A single-cell reference map of transcriptional...
# 8    A versatile approach for assessing human stem ...
# 9    An integrated approach to profile lung tumor e...
# ..                                                 ...
# 139  scRNA-seq analysis of lung CD64-expressing mon...
# 140  scRNA-seq of Anopheles gambiae hemocytes after...
# 141  scRNA-seq of Mus musculus subcutaneous Lin- ce...
# 142  scRNA-seq of human fetal lung primary tissues ...
# 143  scRNA-seq of mouse adipose stem and progenitor...
#
#                      specie specimens min_age max_age ageUnit
# 2    DrosophilaMelanogaster         4      72     120    hour
# 3               HomoSapiens        12      20      69    year
# 5               HomoSapiens        16      50      65    year
# 8               HomoSapiens         1      64      64    year
# 9               HomoSapiens        17      57      74    year
# ..                      ...       ...     ...     ...     ...
# 139             MusMusculus         1      10      29    week
# 140        AnophelesGambiae         3       4       4     day
# 141             MusMusculus         1       8       8    week
# 142             HomoSapiens         9      -1      21    week
# 143             MusMusculus         3       8      10    week
#
# [120 rows x 7 columns]

# %%
specimens = specimens.sort_values(by='projectId')
specimens
# Out:
#                                 projectId  \
# 37   091cf39b-01bc-42e5-9437-f419a66c8a45
# 5    4a95101c-9ffc-4f30-a809-f04518a23803
# 14   4d6f6c96-2a83-43d8-8fe1-0f53bffd4674
# 30   8c3c290d-dfff-4553-8868-54ce45f4ba7f
# 125                             E-CURD-10
# ..                                    ...
# 127  abe1a013-af7a-45ed-8c26-f3793c24a1f4
# 100  ae71be1d-ddd8-4feb-9bed-24c3ddb6e1ad
# 12   cc95ff89-2e68-4a08-a234-480eca21ce79
# 130  f8aa201c-4ff1-45a4-890e-840d63459ca2
# 129  f8aa201c-4ff1-45a4-890e-840d63459ca2
#
#                                           projectTitle       specie specimens  \
# 37   Profiling of CD34+ cells from human bone marro...  HomoSapiens         3
# 5    A single-cell reference map of transcriptional...  HomoSapiens        16
# 14   Dissecting the human liver cellular landscape ...  HomoSapiens         5
# 30   Melanoma infiltration of stromal and immune cells  MusMusculus        54
# 125  Single-cell transcriptome profiling for metast...  HomoSapiens         3
# ..                                                 ...          ...       ...
# 127  Spatio-temporal immune zonation of the human k...  HomoSapiens         6
# 100  Single-cell RNA-seq analysis of human pancreas...  HomoSapiens        10
# 12                              Census of Immune Cells  HomoSapiens       127
# 130  Structural Remodeling of the Human Colonic Mes...  MusMusculus         6
# 129  Structural Remodeling of the Human Colonic Mes...  HomoSapiens        13
#
#     min_age max_age ageUnit
# 37       19      35    year
# 5        50      65    year
# 14       21      65    year
# 30        6      12    week
# 125      43      43    year
# ..      ...     ...     ...
# 127       7      16    week
# 100      22      57    year
# 12        0      52    year
# 130      10      12    week
# 129      29      69    year
#
# [120 rows x 7 columns]

# %%
specimens.to_csv('percentile_specimens.csv', sep=',', index=False)

# %%
query = '''
SELECT 
    gene_name,
    percentile,
    project_id,
    metadata,
    number_genes,
    number_cells
FROM 
    percentiles INNER JOIN percentil_groups ON percentiles.percentil_group = percentil_groups.id
WHERE 
    gene_name IN ('ENSG00000287846', 'ENSDARG00000034326') AND 
    metadata->>'cell type' IN ('MemoryBcell', 'BloodCell') AND 
    metadata->>'organism' = 'HomoSapiens'
'''

# %%
with PostgresConnection() as conn:
    cur = conn.cursor()

    print("Querying number of percentiles")
    cur.execute(query)
    answer = cur.fetchall()
    
    # close communication with the PostgreSQL database server
    cur.close()
    
    display(answer)
# Out:
# Querying number of percentiles
# [('ENSG00000287846',
#   37.29756029749079,
#   'E-MTAB-6386',
#   {'organism': 'HomoSapiens',
#    'cell type': 'MemoryBcell',
#    'developmental stage': 'Adult',
#    'disease': 'Control',
#    'organism part': 'Blood'},
#   14387,
#   30),
#  ('ENSG00000287846',
#   10.537021969080554,
#   'cc95ff89-2e68-4a08-a234-480eca21ce79',
#   {'organism': 'HomoSapiens',
#    'cell type': 'BloodCell',
#    'developmental stage': 'Infant',
#    'organism part': 'UmbilicalCordBlood'},
#   24580,
#   288305)]
