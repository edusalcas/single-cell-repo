# %%
import requests
import json
import pandas as pd

# %% [markdown]
# # All genes

# %%
headers = {'content-type': 'application/json'}
filters = {  
    "project_IDs": [
        "E-MTAB-7303"
    ],
    "cell_types": [
        "DopaminergicNeuron"
    ],
    "disease": [
        "ParkinsonsDisease",
        "Control"
    ]
}

response = requests.get('http://localhost:5001/percentiles', params={'filters': json.dumps(filters)}, headers=headers)
response
# Out:
# <Response [200]>

# %%
percentiles = response.json()
percentiles[0]
# Out:
# {'gene_name': 'ENSG00000000003',
#  'metadata': {'cell type': 'DopaminergicNeuron',
#   'developmental stage': 'Adult',
#   'disease': 'ParkinsonsDisease',
#   'organism': 'HomoSapiens',
#   'organism part': 'Skin'},
#  'number_cells': 37,
#  'number_genes': 15892,
#  'percentile': 58.51371759375786,
#  'project_id': 'E-MTAB-7303'}

# %%
red_percentiles = [{'gene_name': percentil['gene_name'], 'percentile': percentil['percentile'], 'disease': percentil['metadata']['disease']} for percentil in percentiles]
red_percentiles[0]
# Out:
# {'gene_name': 'ENSG00000000003',
#  'percentile': 58.51371759375786,
#  'disease': 'ParkinsonsDisease'}

# %%
percentiles_PD = pd.DataFrame(red_percentiles)
percentiles_PD
# Out:
#              gene_name  percentile            disease
# 0      ENSG00000000003   58.513718  ParkinsonsDisease
# 1      ENSG00000000005    0.000000  ParkinsonsDisease
# 2      ENSG00000000419   27.529575  ParkinsonsDisease
# 3      ENSG00000000457   39.202114  ParkinsonsDisease
# 4      ENSG00000000460   26.000503  ParkinsonsDisease
# ...                ...         ...                ...
# 34083  ENSG00000288550   25.758732            Control
# 34084  ENSG00000288556    1.461697            Control
# 34085  ENSG00000288558    1.990021            Control
# 34086  ENSG00000288564   41.138832            Control
# 34087  ENSG00000288579   48.494276            Control
#
# [34088 rows x 3 columns]

# %%
ax = percentiles_PD.boxplot(by='disease', grid=False)
ax.set_ylabel("Percentile")
ax.set_xlabel("")
ax.set_title("")
plt.show()

# %% [markdown]
# # High Evidence PD genes

# %%
PD_genes = pd.read_csv('Parkinson_Disease_and_Complex_Parkinsonism.csv')
PD_genes = PD_genes.drop(['Unnamed: 0'], axis=1)
PD_genes
# Out:
#    GeneSymbol LevelOfConfidence                 ModeOfInheritance  \
# 0        PRKN      HighEvidence                         biallelic
# 1     ATP13A2      HighEvidence                         biallelic
# 2      ATP1A3      HighEvidence                       monoallelic
# 3    C19orf12      HighEvidence                         biallelic
# 4       CSF1R      HighEvidence                       monoallelic
# 5       DCTN1      HighEvidence                       monoallelic
# 6      DNAJC6      HighEvidence                         biallelic
# 7       FBXO7      HighEvidence                         biallelic
# 8         FTL      HighEvidence                       monoallelic
# 9         GBA      HighEvidence         monoallelic_and_biallelic
# 10       GCH1      HighEvidence         monoallelic_and_biallelic
# 11        GRN      HighEvidence                       monoallelic
# 12      LRRK2      HighEvidence                       monoallelic
# 13       LYST      HighEvidence                         biallelic
# 14       MAPT      HighEvidence                       monoallelic
# 15       OPA3      HighEvidence                         biallelic
# 16      PANK2      HighEvidence                         biallelic
# 17      PARK7      HighEvidence                         biallelic
# 18      PINK1      HighEvidence                         biallelic
# 19     PLA2G6      HighEvidence                         biallelic
# 20      PRKRA      HighEvidence                         biallelic
# 21     RAB39B      HighEvidence               xlinked_monoallelic
# 22   SLC30A10      HighEvidence                         biallelic
# 23   SLC39A14      HighEvidence                         biallelic
# 24     SLC6A3      HighEvidence                         biallelic
# 25       SNCA      HighEvidence                       monoallelic
# 26      SPG11      HighEvidence                         biallelic
# 27        SPR      HighEvidence                         biallelic
# 28      SYNJ1      HighEvidence                         biallelic
# 29         TH      HighEvidence                         biallelic
# 30     TUBB4A      HighEvidence                       monoallelic
# 31     VPS13A      HighEvidence                         biallelic
# 32      VPS35      HighEvidence                       monoallelic
# 33      WDR45      HighEvidence               xlinked_monoallelic
# 34     CHCHD2  ModerateEvidence         monoallelic_not_imprinted
# 35       TAF1  ModerateEvidence               xlinked_monoallelic
# 36       ANO3       LowEvidence                       monoallelic
# 37    ATP6AP2       LowEvidence                 xlinked_biallelic
# 38      ATXN2       LowEvidence                       monoallelic
# 39      ATXN3       LowEvidence                       monoallelic
# 40    C9orf72       LowEvidence                       monoallelic
# 41     EIF4G1       LowEvidence                       monoallelic
# 42     GIGYF2       LowEvidence                               NaN
# 43       GNAL       LowEvidence                       monoallelic
# 44      HTRA2       LowEvidence                       monoallelic
# 45        HTT       LowEvidence                       monoallelic
# 46       IPPK       LowEvidence                         biallelic
# 47       JPH3       LowEvidence         monoallelic_not_imprinted
# 48      NR4A2       LowEvidence                         biallelic
# 49       SGCE       LowEvidence  monoallelic_maternally_imprinted
# 50    SLC41A1       LowEvidence                               NaN
# 51     SNCAIP       LowEvidence                         biallelic
# 52        TBP       LowEvidence                       monoallelic
# 53      THAP1       LowEvidence                       monoallelic
# 54      TOR1A       LowEvidence                       monoallelic
# 55      UCHL1       LowEvidence                       monoallelic
# 56      EPHB4            NoList                               NaN
#
#                                   ModeOfPathogenicity
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Loss-of-function variants (as defined in pop u...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25     Other - please provide details in the comments
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35     Other - please provide details in the comments
# 36                                                NaN
# 37                                                NaN
# 38  Loss-of-function variants (as defined in pop u...
# 39  Loss-of-function variants (as defined in pop u...
# 40  Loss-of-function variants (as defined in pop u...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  Loss-of-function variants (as defined in pop u...
# 46                                                NaN
# 47     Other - please provide details in the comments
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  Loss-of-function variants (as defined in pop u...
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56  Loss-of-function variants (as defined in pop u...

# %%
gene_dict = pd.read_csv('dictionary_genes.tsv', sep='\t')
gene_dict
# Out:
#                HGCN          ensembl
# 0            TSPAN6  ENSG00000000003
# 1              DPM1  ENSG00000000419
# 2             SCYL3  ENSG00000000457
# 3          C1orf112  ENSG00000000460
# 4               FGR  ENSG00000000938
# ...             ...              ...
# 16866     NOTCH2NLC  ENSG00000286219
# 16867       SPDYE11  ENSG00000286228
# 16868          H3C2  ENSG00000286522
# 16869          H3C3  ENSG00000287080
# 16870  DUS4L-BCAP29  ENSG00000288558
#
# [16871 rows x 2 columns]

# %%
PD_genes_HighEvidence = PD_genes[PD_genes['LevelOfConfidence'] == "HighEvidence"]['GeneSymbol'].to_list()

# %%
PD_HighEvidence_gene_dict = gene_dict[gene_dict['HGCN'].isin(PD_genes_HighEvidence)]
PD_HighEvidence_gene_dict
# Out:
#            HGCN          ensembl
# 427         GRN  ENSG00000030582
# 946       VPS35  ENSG00000069329
# 1526        FTL  ENSG00000087086
# 1951      FBXO7  ENSG00000100225
# 2498      SPG11  ENSG00000104133
# 2552   SLC39A14  ENSG00000104635
# 2578     TUBB4A  ENSG00000104833
# 2688     ATP1A3  ENSG00000105409
# 3910      PARK7  ENSG00000116288
# 3942     DNAJC6  ENSG00000116675
# 4823       OPA3  ENSG00000125741
# 4830      PANK2  ENSG00000125779
# 5455   C19orf12  ENSG00000131943
# 5459       GCH1  ENSG00000131979
# 7051       LYST  ENSG00000143669
# 7242       SNCA  ENSG00000145335
# 8240     RAB39B  ENSG00000155961
# 8515      PINK1  ENSG00000158828
# 8535      SYNJ1  ENSG00000159082
# 8573    ATP13A2  ENSG00000159363
# 11418       GBA  ENSG00000177628
# 11709     PRKRA  ENSG00000180228
# 11982     CSF1R  ENSG00000182578
# 12243    PLA2G6  ENSG00000184381
# 12386      PRKN  ENSG00000185345
# 12623      MAPT  ENSG00000186868
# 12892     LRRK2  ENSG00000188906
# 13115  SLC30A10  ENSG00000196660
# 13180     WDR45  ENSG00000196998
# 13384    VPS13A  ENSG00000197969
# 13866     DCTN1  ENSG00000204843

# %%
def ensembl2HGCN(gene_name):
    return gene_dict[gene_dict['ensembl'] == gene_name]['HGCN'].iloc[0]

def HGCN2ensembl(gene_name):
    return gene_dict[gene_dict['HGCN'] == gene_name]['ensembl'].iloc[0]

# %%
HGCN2ensembl("DCTN1")
# Out:
# 'ENSG00000204843'

# %%
print(f"We have {len(PD_genes_HighEvidence)} genes with high evidence in PD, {len(PD_HighEvidence_gene_dict)}/{len(PD_genes_HighEvidence)} in ensembl format.")
# Out:
# We have 34 genes with high evidence in PD, 31/34 in ensembl format.

# %%
PD_gene_HighEvidence_ensembl = PD_HighEvidence_gene_dict['ensembl'].to_list()
PD_gene_HighEvidence_ensembl
# Out:
# ['ENSG00000030582',
#  'ENSG00000069329',
#  'ENSG00000087086',
#  'ENSG00000100225',
#  'ENSG00000104133',
#  'ENSG00000104635',
#  'ENSG00000104833',
#  'ENSG00000105409',
#  'ENSG00000116288',
#  'ENSG00000116675',
#  'ENSG00000125741',
#  'ENSG00000125779',
#  'ENSG00000131943',
#  'ENSG00000131979',
#  'ENSG00000143669',
#  'ENSG00000145335',
#  'ENSG00000155961',
#  'ENSG00000158828',
#  'ENSG00000159082',
#  'ENSG00000159363',
#  'ENSG00000177628',
#  'ENSG00000180228',
#  'ENSG00000182578',
#  'ENSG00000184381',
#  'ENSG00000185345',
#  'ENSG00000186868',
#  'ENSG00000188906',
#  'ENSG00000196660',
#  'ENSG00000196998',
#  'ENSG00000197969',
#  'ENSG00000204843']

# %%
headers = {'content-type': 'application/json'}
filters = {  
    "project_IDs": [
        "E-MTAB-7303"
    ],
    "gen_names":
        PD_gene_HighEvidence_ensembl
    ,
    "cell_types": [
        "DopaminergicNeuron"
    ],
    "disease": [
        "ParkinsonsDisease",
        "Control"
    ]
}

response = requests.get('http://localhost:5001/percentiles', params={'filters': json.dumps(filters)}, headers=headers)
response
# Out:
# <Response [200]>

# %%
percentiles = response.json()
percentiles[0]
# Out:
# {'gene_name': 'ENSG00000030582',
#  'metadata': {'cell type': 'DopaminergicNeuron',
#   'developmental stage': 'Adult',
#   'disease': 'ParkinsonsDisease',
#   'organism': 'HomoSapiens',
#   'organism part': 'Skin'},
#  'number_cells': 37,
#  'number_genes': 15892,
#  'percentile': 93.8963000251699,
#  'project_id': 'E-MTAB-7303'}

# %%
red_percentiles = [{'gene_name': ensembl2HGCN(percentil['gene_name']), 'percentile': percentil['percentile'], 'disease': percentil['metadata']['disease']} for percentil in percentiles]
red_percentiles
# Out:
# [{'gene_name': 'GRN',
#   'percentile': 93.8963000251699,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'VPS35',
#   'percentile': 83.79687893279637,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'FTL',
#   'percentile': 99.89302793858545,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'FBXO7',
#   'percentile': 94.41228290964007,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'SPG11',
#   'percentile': 82.45658192801409,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'SLC39A14',
#   'percentile': 30.43669770953939,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'TUBB4A',
#   'percentile': 74.93078278379059,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'ATP1A3',
#   'percentile': 49.068713818273345,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'PARK7',
#   'percentile': 98.03045557513215,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'DNAJC6',
#   'percentile': 87.31437201107475,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'OPA3',
#   'percentile': 60.514724389630004,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'PANK2',
#   'percentile': 46.94185753838409,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'C19orf12',
#   'percentile': 30.726151522778757,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'GCH1',
#   'percentile': 40.02013591744274,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'LYST',
#   'percentile': 73.98691165366222,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'SNCA',
#   'percentile': 24.100176189277626,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'RAB39B',
#   'percentile': 26.856279889252455,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'PINK1',
#   'percentile': 82.8404228542663,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'SYNJ1',
#   'percentile': 54.49911905361188,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'ATP13A2',
#   'percentile': 78.95796627233828,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'GBA',
#   'percentile': 76.23332494336773,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'PRKRA',
#   'percentile': 57.55096904102693,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'PLA2G6',
#   'percentile': 40.21520261766926,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'PRKN',
#   'percentile': 42.05889755852001,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'MAPT',
#   'percentile': 83.99194563302291,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'SLC30A10', 'percentile': 0.0, 'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'WDR45',
#   'percentile': 68.0719859048578,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'VPS13A',
#   'percentile': 68.27334507928518,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'DCTN1',
#   'percentile': 89.85023911401964,
#   'disease': 'ParkinsonsDisease'},
#  {'gene_name': 'GRN', 'percentile': 90.47255650132081, 'disease': 'Control'},
#  {'gene_name': 'VPS35', 'percentile': 89.35133548576461, 'disease': 'Control'},
#  {'gene_name': 'FTL', 'percentile': 99.90607572644555, 'disease': 'Control'},
#  {'gene_name': 'FBXO7', 'percentile': 87.78984443792193, 'disease': 'Control'},
#  {'gene_name': 'SPG11', 'percentile': 77.1940123275609, 'disease': 'Control'},
#  {'gene_name': 'SLC39A14',
#   'percentile': 35.59729967713531,
#   'disease': 'Control'},
#  {'gene_name': 'TUBB4A',
#   'percentile': 76.92398004109187,
#   'disease': 'Control'},
#  {'gene_name': 'ATP1A3',
#   'percentile': 79.91194599354272,
#   'disease': 'Control'},
#  {'gene_name': 'PARK7', 'percentile': 98.21543880246551, 'disease': 'Control'},
#  {'gene_name': 'DNAJC6',
#   'percentile': 92.50366891693572,
#   'disease': 'Control'},
#  {'gene_name': 'OPA3', 'percentile': 19.577340769004987, 'disease': 'Control'},
#  {'gene_name': 'PANK2', 'percentile': 58.09803346052246, 'disease': 'Control'},
#  {'gene_name': 'C19orf12',
#   'percentile': 66.67449368946286,
#   'disease': 'Control'},
#  {'gene_name': 'GCH1', 'percentile': 21.273847960082186, 'disease': 'Control'},
#  {'gene_name': 'LYST', 'percentile': 64.12092750220135, 'disease': 'Control'},
#  {'gene_name': 'SNCA', 'percentile': 72.46257704725565, 'disease': 'Control'},
#  {'gene_name': 'RAB39B',
#   'percentile': 49.46874082770766,
#   'disease': 'Control'},
#  {'gene_name': 'PINK1', 'percentile': 84.96037569709422, 'disease': 'Control'},
#  {'gene_name': 'SYNJ1', 'percentile': 31.58203698268271, 'disease': 'Control'},
#  {'gene_name': 'ATP13A2',
#   'percentile': 93.92427355444673,
#   'disease': 'Control'},
#  {'gene_name': 'GBA', 'percentile': 82.64749046081596, 'disease': 'Control'},
#  {'gene_name': 'PRKRA', 'percentile': 80.20545934840035, 'disease': 'Control'},
#  {'gene_name': 'PLA2G6',
#   'percentile': 31.400058702670968,
#   'disease': 'Control'},
#  {'gene_name': 'PRKN', 'percentile': 76.28999119459935, 'disease': 'Control'},
#  {'gene_name': 'MAPT', 'percentile': 94.23539771059583, 'disease': 'Control'},
#  {'gene_name': 'SLC30A10',
#   'percentile': 10.038156736131494,
#   'disease': 'Control'},
#  {'gene_name': 'WDR45', 'percentile': 87.84854710889346, 'disease': 'Control'},
#  {'gene_name': 'VPS13A',
#   'percentile': 59.05488699735838,
#   'disease': 'Control'},
#  {'gene_name': 'DCTN1', 'percentile': 93.64837100088053, 'disease': 'Control'}]

# %%
percentiles_PD = pd.DataFrame(red_percentiles)
percentiles_PD
# Out:
#    gene_name  percentile            disease
# 0        GRN   93.896300  ParkinsonsDisease
# 1      VPS35   83.796879  ParkinsonsDisease
# 2        FTL   99.893028  ParkinsonsDisease
# 3      FBXO7   94.412283  ParkinsonsDisease
# 4      SPG11   82.456582  ParkinsonsDisease
# 5   SLC39A14   30.436698  ParkinsonsDisease
# 6     TUBB4A   74.930783  ParkinsonsDisease
# 7     ATP1A3   49.068714  ParkinsonsDisease
# 8      PARK7   98.030456  ParkinsonsDisease
# 9     DNAJC6   87.314372  ParkinsonsDisease
# 10      OPA3   60.514724  ParkinsonsDisease
# 11     PANK2   46.941858  ParkinsonsDisease
# 12  C19orf12   30.726152  ParkinsonsDisease
# 13      GCH1   40.020136  ParkinsonsDisease
# 14      LYST   73.986912  ParkinsonsDisease
# 15      SNCA   24.100176  ParkinsonsDisease
# 16    RAB39B   26.856280  ParkinsonsDisease
# 17     PINK1   82.840423  ParkinsonsDisease
# 18     SYNJ1   54.499119  ParkinsonsDisease
# 19   ATP13A2   78.957966  ParkinsonsDisease
# 20       GBA   76.233325  ParkinsonsDisease
# 21     PRKRA   57.550969  ParkinsonsDisease
# 22    PLA2G6   40.215203  ParkinsonsDisease
# 23      PRKN   42.058898  ParkinsonsDisease
# 24      MAPT   83.991946  ParkinsonsDisease
# 25  SLC30A10    0.000000  ParkinsonsDisease
# 26     WDR45   68.071986  ParkinsonsDisease
# 27    VPS13A   68.273345  ParkinsonsDisease
# 28     DCTN1   89.850239  ParkinsonsDisease
# 29       GRN   90.472557            Control
# 30     VPS35   89.351335            Control
# 31       FTL   99.906076            Control
# 32     FBXO7   87.789844            Control
# 33     SPG11   77.194012            Control
# 34  SLC39A14   35.597300            Control
# 35    TUBB4A   76.923980            Control
# 36    ATP1A3   79.911946            Control
# 37     PARK7   98.215439            Control
# 38    DNAJC6   92.503669            Control
# 39      OPA3   19.577341            Control
# 40     PANK2   58.098033            Control
# 41  C19orf12   66.674494            Control
# 42      GCH1   21.273848            Control
# 43      LYST   64.120928            Control
# 44      SNCA   72.462577            Control
# 45    RAB39B   49.468741            Control
# 46     PINK1   84.960376            Control
# 47     SYNJ1   31.582037            Control
# 48   ATP13A2   93.924274            Control
# 49       GBA   82.647490            Control
# 50     PRKRA   80.205459            Control
# 51    PLA2G6   31.400059            Control
# 52      PRKN   76.289991            Control
# 53      MAPT   94.235398            Control
# 54  SLC30A10   10.038157            Control
# 55     WDR45   87.848547            Control
# 56    VPS13A   59.054887            Control
# 57     DCTN1   93.648371            Control

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

rcParams['figure.figsize'] = (15, 9)
rcParams['font.size'] = 14

# %%
ax = percentiles_PD.boxplot(by='disease', grid=False)
ax.set_ylabel("Percentile")
ax.set_xlabel("")
ax.set_title("")
plt.show()

# %%
diff = [a - b for a, b in zip(percentiles_PD[percentiles_PD['disease']=='Control']['percentile'].to_list(),
                              percentiles_PD[percentiles_PD['disease']=='ParkinsonsDisease']['percentile'].to_list())]
diff
# Out:
# [-3.423743523849083,
#  5.554456552968233,
#  0.013047787860102744,
#  -6.622438471718141,
#  -5.26256960045319,
#  5.16060196759592,
#  1.9931972573012757,
#  30.84323217526937,
#  0.1849832273333618,
#  5.189296905860971,
#  -40.93738362062501,
#  11.156175922138367,
#  35.94834216668411,
#  -18.74628795736055,
#  -9.865984151460864,
#  48.362400857978024,
#  22.612460938455207,
#  2.119952842827928,
#  -22.91708207092917,
#  14.966307282108446,
#  6.414165517448225,
#  22.654490307373422,
#  -8.815143914998295,
#  34.23109363607934,
#  10.243452077572925,
#  10.038156736131494,
#  19.77656120403566,
#  -9.218458081926798,
#  3.7981318868608867]

# %%
diff_df = pd.DataFrame({
    'gene_name': percentiles_PD[percentiles_PD['disease']=='ParkinsonsDisease']['gene_name'].to_list(),
    'diff': diff
})
diff_df
# Out:
#    gene_name       diff
# 0        GRN  -3.423744
# 1      VPS35   5.554457
# 2        FTL   0.013048
# 3      FBXO7  -6.622438
# 4      SPG11  -5.262570
# 5   SLC39A14   5.160602
# 6     TUBB4A   1.993197
# 7     ATP1A3  30.843232
# 8      PARK7   0.184983
# 9     DNAJC6   5.189297
# 10      OPA3 -40.937384
# 11     PANK2  11.156176
# 12  C19orf12  35.948342
# 13      GCH1 -18.746288
# 14      LYST  -9.865984
# 15      SNCA  48.362401
# 16    RAB39B  22.612461
# 17     PINK1   2.119953
# 18     SYNJ1 -22.917082
# 19   ATP13A2  14.966307
# 20       GBA   6.414166
# 21     PRKRA  22.654490
# 22    PLA2G6  -8.815144
# 23      PRKN  34.231094
# 24      MAPT  10.243452
# 25  SLC30A10  10.038157
# 26     WDR45  19.776561
# 27    VPS13A  -9.218458
# 28     DCTN1   3.798132

# %%
diff_df.plot.bar(x='gene_name', y = 'diff')
# Out:
# <AxesSubplot:xlabel='gene_name'>
