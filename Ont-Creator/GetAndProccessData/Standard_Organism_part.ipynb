# %%
import requests
import pandas as pd
import urllib.parse
import json
import time
import re

from IPython.display import clear_output
from GetTermsOntobee import get_URI_from_name, get_name_from_URI

# %% [markdown]
# # SCEA organism parts

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
ontologies = ['EFO', 'UBERON', 'CL', 'PO', 'ZFA']

# %%
def get_terms_from_project(experiment_id, name_column, ontology_column):
    terms = []
    terms_names = []
    
    experiment_metadata = f"https://www.ebi.ac.uk/gxa/sc/experiment/{experiment_id}/download?fileType=experiment-design&accessKey="
    
    df = pd.read_csv(experiment_metadata, sep='\t', low_memory=False)
            
    if name_column in df.columns:
        project_term_names = df[name_column].unique()
        project_term_URIs = df[ontology_column].unique()
    
        # Balance names and URIs
        project_term_URIs = list(project_term_URIs)
        project_term_URIs += [None] * (len(project_term_names) - len(project_term_URIs))
        
        for name, URI in zip(project_term_names, project_term_URIs):
            # If we have already code the cell_type we skip it
            if name in terms_names:
                continue
            
            print(name)
            
            # If we have no info of URI we search for it
            if URI is None or str(URI) == 'nan':
                for ontology in ontologies:
                    
                    URI = get_URI_from_name(name, ontology)
                    time.sleep(1)
                    
                    if URI is not None:
                        terms.append({
                            'name': name,
                            'URI': URI
                        })
                
                if URI is None:
                    URI = get_URI_from_name(name)
                    time.sleep(1)
                    
                    terms.append({
                        'name': name,
                        'URI': URI
                    })
                    
            # Otherwise   
            else:                    
                terms_names.append(name)

                terms.append({
                    'name': name,
                    'URI': URI
                })
                
            # If there are two or more cell types in the name
            if URI is None:
                new_l = re.split(' and |, |; ', name)
                for new_name in new_l:
                    
                    for ontology in ontologies:
                        
                        URI = get_URI_from_name(new_name, ontology)
                        time.sleep(1)
                        
                        if URI is not None:

                            terms.append({
                                'name': new_name,
                                'URI': URI
                            })
                    
                    if URI is None:
                        URI = get_URI_from_name(name)
                        time.sleep(1)

                        terms.append({
                            'name': name,
                            'URI': URI
                        })
                        
                    terms_names.append(new_name)
            

    return terms, terms_names

# %%
organism_parts = []
organism_part_names = []
avoid_collections = ["Human Cell Atlas"]

n_experiments = len(answer.json()['experiments'])

for n, experiment in enumerate(answer.json()['experiments']):
    print(f"{n+1}/{n_experiments}")

    if [i for i in experiment["experimentProjects"] if i in avoid_collections]:
        clear_output(wait=True)
        continue
    
    experiment_id = experiment['experimentAccession']
    organism_parts_pro, organism_part_names_pro = get_terms_from_project(experiment_id=experiment_id, 
                                                             name_column='Sample Characteristic[organism part]', 
                                                             ontology_column='Sample Characteristic Ontology Term[organism part]')
    
    organism_parts += organism_parts_pro
    organism_part_names += organism_part_names_pro
    
    clear_output(wait=True)

df_SCEA = pd.DataFrame(organism_parts)
# Out:
# 181/181
# blood

# %%
df_SCEA = df_SCEA.drop_duplicates()

# %%
df_SCEA[df_SCEA.isnull().any(axis=1)].name.tolist()
# Out:
# ['smooth muscle, peri-urethral mesenchyme and urethral epithelium',
#  'dorsal medial ganglionic eminence',
#  'pigmented layer of retina and optic choroid',
#  'primary visual area, layer 1, layer 2/3 and layer 4',
#  'primary visual area, layer 1',
#  'brain without olfactory bulb']

# %%
from OntologyConversorSCAE import OntologyConversorSCAE

conversor_SCAE = OntologyConversorSCAE()

# %%
df = df_SCEA
df['name'] = df['name'].apply(conversor_SCAE.parse_word)
df
# Out:
#                       name                                            URI
# 0                   Kidney  http://purl.obolibrary.org/obo/UBERON_0002113
# 1               Bronchiole  http://purl.obolibrary.org/obo/UBERON_0002186
# 2    MiddleLobeOfRightLung  http://purl.obolibrary.org/obo/UBERON_0002174
# 3                     Lung  http://purl.obolibrary.org/obo/UBERON_0002048
# 4               PedalDigit  http://purl.obolibrary.org/obo/UBERON_0006051
# ..                     ...                                            ...
# 452                 Caecum  http://purl.obolibrary.org/obo/UBERON_0001153
# 453   RectoSigmoidJunction  http://purl.obolibrary.org/obo/UBERON_0036214
# 454           SigmoidColon  http://purl.obolibrary.org/obo/UBERON_0001159
# 456         AscendingColon  http://purl.obolibrary.org/obo/UBERON_0001156
# 458        PeritonealFluid  http://purl.obolibrary.org/obo/UBERON_0001268
#
# [154 rows x 2 columns]

# %% [markdown]
# # HCA diseases

# %%
seed_url = "https://service.azul.data.humancellatlas.org/index/projects?size=999&catalog=dcp1"

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)
project_hits = answer.json()["hits"]

# %%
n_projects = len(project_hits)

organism_parts = []

for n, hit in enumerate(project_hits):
    print(n)
    
    for item in hit['specimens']:
        organism_parts += item['organ']
        organism_parts += item['organPart']
        
    clear_output(wait=True)
    
organism_parts = list(set(organism_parts))
# Out:
# 27

# %%
organism_parts = [x for x in organism_parts if x is not None]
organism_parts
# Out:
# ['caudate lobe',
#  'esophagus',
#  'renal medulla',
#  'parietal endoderm',
#  'lymph node',
#  'lung parenchyma',
#  'lower lobe of left lung',
#  'cortex',
#  'peripheral blood mononuclear cell',
#  'mammary gland',
#  'presumptive gut',
#  'lower lobe of right lung',
#  'hematopoietic system',
#  'umbilical cord blood',
#  'venous blood',
#  'skin of body',
#  'Left lateral basal bronchopulmonary segment',
#  'decidua',
#  'placenta',
#  'mediastinal lymph node',
#  'kidney',
#  'trachea',
#  'blood',
#  'blastocyst',
#  'ureter',
#  'bladder organ',
#  'cortex of kidney',
#  'islet of Langerhans',
#  'immune system',
#  'retina',
#  'visceral endoderm',
#  'lung',
#  'bone tissue',
#  'heart',
#  'tongue',
#  'muscle organ',
#  'diaphragm',
#  'definitive endoderm',
#  'pancreas',
#  'retinal neural layer',
#  'renal pelvis',
#  'large intestine',
#  'eye',
#  'bone marrow',
#  'endoderm',
#  'esophagus mucosa',
#  'brain',
#  'spleen',
#  'colon',
#  'thymus',
#  'fovea centralis',
#  'liver',
#  'yolk sac endoderm',
#  'lamina propria of mucosa of colon',
#  'embryo',
#  'adipose tissue',
#  'tumor',
#  'skin epidermis']

# %%
organism_parts_URIs = list(map(get_URI_from_name, organism_parts))
organism_parts_URIs
# Out:
# ['http://purl.obolibrary.org/obo/EHDA_10432',
#  'http://purl.obolibrary.org/obo/UBERON_0001043',
#  'http://purl.obolibrary.org/obo/UBERON_0000362',
#  'http://purl.obolibrary.org/obo/UBERON_0008800',
#  'http://purl.obolibrary.org/obo/BTO_0000784',
#  'http://purl.obolibrary.org/obo/UBERON_0008946',
#  'http://purl.obolibrary.org/obo/UBERON_0008953',
#  'http://purl.obolibrary.org/obo/PO_0005708',
#  'http://purl.obolibrary.org/obo/CL_2000001',
#  'http://purl.obolibrary.org/obo/UBERON_0001911',
#  'http://purl.obolibrary.org/obo/UBERON_0007026',
#  'http://purl.obolibrary.org/obo/UBERON_0002171',
#  'http://purl.obolibrary.org/obo/UBERON_0002390',
#  'http://purl.obolibrary.org/obo/UBERON_0012168',
#  'http://purl.obolibrary.org/obo/UBERON_0013756',
#  'http://purl.obolibrary.org/obo/UBERON_0002097',
#  'http://purl.obolibrary.org/obo/FMA_7379',
#  'http://purl.obolibrary.org/obo/UBERON_0002450',
#  'http://purl.obolibrary.org/obo/BTO_0001078',
#  'http://purl.obolibrary.org/obo/UBERON_0002524',
#  'http://purl.obolibrary.org/obo/UBERON_0002113',
#  'http://purl.obolibrary.org/obo/UBERON_0003126',
#  'http://purl.obolibrary.org/obo/NCRO_0000105',
#  'http://purl.obolibrary.org/obo/UBERON_0000358',
#  'http://purl.obolibrary.org/obo/UBERON_0000056',
#  'http://purl.obolibrary.org/obo/UBERON_0018707',
#  'http://purl.obolibrary.org/obo/UBERON_0001225',
#  'http://purl.obolibrary.org/obo/UBERON_0000006',
#  'http://purl.obolibrary.org/obo/UBERON_0002405',
#  'http://purl.obolibrary.org/obo/UBERON_0000966',
#  'http://purl.obolibrary.org/obo/UBERON_0004877',
#  'http://purl.obolibrary.org/obo/UBERON_0002048',
#  'http://purl.obolibrary.org/obo/UBERON_0002481',
#  'http://purl.obolibrary.org/obo/UBERON_0000948',
#  'http://purl.obolibrary.org/obo/UBERON_0001723',
#  'http://purl.obolibrary.org/obo/UBERON_0001630',
#  'http://purl.obolibrary.org/obo/UBERON_0001103',
#  'http://purl.obolibrary.org/obo/UBERON_0005439',
#  'http://purl.obolibrary.org/obo/UBERON_0001264',
#  'http://purl.obolibrary.org/obo/UBERON_0003902',
#  'http://purl.obolibrary.org/obo/UBERON_0001224',
#  'http://purl.obolibrary.org/obo/UBERON_0000059',
#  'http://purl.obolibrary.org/obo/OMIT_0006347',
#  'http://purl.obolibrary.org/obo/UBERON_0002371',
#  'http://purl.obolibrary.org/obo/NCRO_0000112',
#  'http://purl.obolibrary.org/obo/UBERON_0002469',
#  'http://purl.obolibrary.org/obo/UBERON_0000955',
#  'http://purl.obolibrary.org/obo/UBERON_0002106',
#  'http://purl.obolibrary.org/obo/UBERON_0001155',
#  'http://purl.obolibrary.org/obo/UBERON_0002370',
#  'http://purl.obolibrary.org/obo/UBERON_0001786',
#  'http://purl.obolibrary.org/obo/UBERON_0002107',
#  'http://purl.obolibrary.org/obo/UBERON_0003257',
#  'http://purl.obolibrary.org/obo/UBERON_0007177',
#  'http://purl.obolibrary.org/obo/IDOMAL_0000646',
#  'http://purl.obolibrary.org/obo/UBERON_0001013',
#  'http://purl.obolibrary.org/obo/ICDO_0000104',
#  'http://purl.obolibrary.org/obo/UBERON_0001003']

# %%
from OntologyConversorHCA import OntologyConversorHCA

conversor_HCA = OntologyConversorHCA()

# %%
organism_parts = list(map(conversor_HCA.parse_word, organism_parts))
organism_parts
# Out:
# ['CaudateLobe',
#  'Esophagus',
#  'RenalMedulla',
#  'ParietalEndoderm',
#  'LymphNode',
#  'LungParenchyma',
#  'LowerLobeOfLeftLung',
#  'Cortex',
#  'PeripheralBloodMononuclearCell',
#  'MammaryGland',
#  'presumptiveGut',
#  'LowerLobeOfRightLung',
#  'HematopoieticSystem',
#  'UmbilicalCordBlood',
#  'VenousBlood',
#  'Skin',
#  'LeftLateralBasalBronchopulmonarySegment',
#  'Decidua',
#  'Placenta',
#  'MediastinalLymphNode',
#  'Kidney',
#  'Trachea',
#  'Blood',
#  'Blastocyst',
#  'Ureter',
#  'Bladder',
#  'CortexOfKidney',
#  'IsletOfLangerhans',
#  'ImmuneSystem',
#  'Retina',
#  'VisceralEndoderm',
#  'Lung',
#  'BoneTissue',
#  'Heart',
#  'Tongue',
#  'Muscle',
#  'Diaphragm',
#  'DefinitiveEndoderm',
#  'Pancreas',
#  'RetinalNeuralLayer',
#  'RenalPelvis',
#  'LargeIntestine',
#  'Eye',
#  'BoneMarrow',
#  'Endoderm',
#  'EsophagusMucosa',
#  'Brain',
#  'Spleen',
#  'Colon',
#  'Thymus',
#  'FoveaCentralis',
#  'Liver',
#  'YolkSacEndoderm',
#  'LaminaPropriaOfMucosaOfColon',
#  'Embryo',
#  'AdiposeTissue',
#  'Tumor',
#  'Epidermis']

# %%
rows = pd.DataFrame({'name': organism_parts, 'URI': organism_parts_URIs})
rows
# Out:
#                                        name  \
# 0                               CaudateLobe
# 1                                 Esophagus
# 2                              RenalMedulla
# 3                          ParietalEndoderm
# 4                                 LymphNode
# 5                            LungParenchyma
# 6                       LowerLobeOfLeftLung
# 7                                    Cortex
# 8            PeripheralBloodMononuclearCell
# 9                              MammaryGland
# 10                           presumptiveGut
# 11                     LowerLobeOfRightLung
# 12                      HematopoieticSystem
# 13                       UmbilicalCordBlood
# 14                              VenousBlood
# 15                                     Skin
# 16  LeftLateralBasalBronchopulmonarySegment
# 17                                  Decidua
# 18                                 Placenta
# 19                     MediastinalLymphNode
# 20                                   Kidney
# 21                                  Trachea
# 22                                    Blood
# 23                               Blastocyst
# 24                                   Ureter
# 25                                  Bladder
# 26                           CortexOfKidney
# 27                        IsletOfLangerhans
# 28                             ImmuneSystem
# 29                                   Retina
# 30                         VisceralEndoderm
# 31                                     Lung
# 32                               BoneTissue
# 33                                    Heart
# 34                                   Tongue
# 35                                   Muscle
# 36                                Diaphragm
# 37                       DefinitiveEndoderm
# 38                                 Pancreas
# 39                       RetinalNeuralLayer
# 40                              RenalPelvis
# 41                           LargeIntestine
# 42                                      Eye
# 43                               BoneMarrow
# 44                                 Endoderm
# 45                          EsophagusMucosa
# 46                                    Brain
# 47                                   Spleen
# 48                                    Colon
# 49                                   Thymus
# 50                           FoveaCentralis
# 51                                    Liver
# 52                          YolkSacEndoderm
# 53             LaminaPropriaOfMucosaOfColon
# 54                                   Embryo
# 55                            AdiposeTissue
# 56                                    Tumor
# 57                                Epidermis
#
#                                               URI
# 0       http://purl.obolibrary.org/obo/EHDA_10432
# 1   http://purl.obolibrary.org/obo/UBERON_0001043
# 2   http://purl.obolibrary.org/obo/UBERON_0000362
# 3   http://purl.obolibrary.org/obo/UBERON_0008800
# 4      http://purl.obolibrary.org/obo/BTO_0000784
# 5   http://purl.obolibrary.org/obo/UBERON_0008946
# 6   http://purl.obolibrary.org/obo/UBERON_0008953
# 7       http://purl.obolibrary.org/obo/PO_0005708
# 8       http://purl.obolibrary.org/obo/CL_2000001
# 9   http://purl.obolibrary.org/obo/UBERON_0001911
# 10  http://purl.obolibrary.org/obo/UBERON_0007026
# 11  http://purl.obolibrary.org/obo/UBERON_0002171
# 12  http://purl.obolibrary.org/obo/UBERON_0002390
# 13  http://purl.obolibrary.org/obo/UBERON_0012168
# 14  http://purl.obolibrary.org/obo/UBERON_0013756
# 15  http://purl.obolibrary.org/obo/UBERON_0002097
# 16        http://purl.obolibrary.org/obo/FMA_7379
# 17  http://purl.obolibrary.org/obo/UBERON_0002450
# 18     http://purl.obolibrary.org/obo/BTO_0001078
# 19  http://purl.obolibrary.org/obo/UBERON_0002524
# 20  http://purl.obolibrary.org/obo/UBERON_0002113
# 21  http://purl.obolibrary.org/obo/UBERON_0003126
# 22    http://purl.obolibrary.org/obo/NCRO_0000105
# 23  http://purl.obolibrary.org/obo/UBERON_0000358
# 24  http://purl.obolibrary.org/obo/UBERON_0000056
# 25  http://purl.obolibrary.org/obo/UBERON_0018707
# 26  http://purl.obolibrary.org/obo/UBERON_0001225
# 27  http://purl.obolibrary.org/obo/UBERON_0000006
# 28  http://purl.obolibrary.org/obo/UBERON_0002405
# 29  http://purl.obolibrary.org/obo/UBERON_0000966
# 30  http://purl.obolibrary.org/obo/UBERON_0004877
# 31  http://purl.obolibrary.org/obo/UBERON_0002048
# 32  http://purl.obolibrary.org/obo/UBERON_0002481
# 33  http://purl.obolibrary.org/obo/UBERON_0000948
# 34  http://purl.obolibrary.org/obo/UBERON_0001723
# 35  http://purl.obolibrary.org/obo/UBERON_0001630
# 36  http://purl.obolibrary.org/obo/UBERON_0001103
# 37  http://purl.obolibrary.org/obo/UBERON_0005439
# 38  http://purl.obolibrary.org/obo/UBERON_0001264
# 39  http://purl.obolibrary.org/obo/UBERON_0003902
# 40  http://purl.obolibrary.org/obo/UBERON_0001224
# 41  http://purl.obolibrary.org/obo/UBERON_0000059
# 42    http://purl.obolibrary.org/obo/OMIT_0006347
# 43  http://purl.obolibrary.org/obo/UBERON_0002371
# 44    http://purl.obolibrary.org/obo/NCRO_0000112
# 45  http://purl.obolibrary.org/obo/UBERON_0002469
# 46  http://purl.obolibrary.org/obo/UBERON_0000955
# 47  http://purl.obolibrary.org/obo/UBERON_0002106
# 48  http://purl.obolibrary.org/obo/UBERON_0001155
# 49  http://purl.obolibrary.org/obo/UBERON_0002370
# 50  http://purl.obolibrary.org/obo/UBERON_0001786
# 51  http://purl.obolibrary.org/obo/UBERON_0002107
# 52  http://purl.obolibrary.org/obo/UBERON_0003257
# 53  http://purl.obolibrary.org/obo/UBERON_0007177
# 54  http://purl.obolibrary.org/obo/IDOMAL_0000646
# 55  http://purl.obolibrary.org/obo/UBERON_0001013
# 56    http://purl.obolibrary.org/obo/ICDO_0000104
# 57  http://purl.obolibrary.org/obo/UBERON_0001003

# %%
df = df.append(rows, ignore_index=True).drop_duplicates()
df
# Out:
#                              name  \
# 0                          Kidney
# 1                      Bronchiole
# 2           MiddleLobeOfRightLung
# 3                            Lung
# 4                      PedalDigit
# ..                            ...
# 204                FoveaCentralis
# 206               YolkSacEndoderm
# 207  LaminaPropriaOfMucosaOfColon
# 208                        Embryo
# 210                         Tumor
#
#                                                URI
# 0    http://purl.obolibrary.org/obo/UBERON_0002113
# 1    http://purl.obolibrary.org/obo/UBERON_0002186
# 2    http://purl.obolibrary.org/obo/UBERON_0002174
# 3    http://purl.obolibrary.org/obo/UBERON_0002048
# 4    http://purl.obolibrary.org/obo/UBERON_0006051
# ..                                             ...
# 204  http://purl.obolibrary.org/obo/UBERON_0001786
# 206  http://purl.obolibrary.org/obo/UBERON_0003257
# 207  http://purl.obolibrary.org/obo/UBERON_0007177
# 208  http://purl.obolibrary.org/obo/IDOMAL_0000646
# 210    http://purl.obolibrary.org/obo/ICDO_0000104
#
# [183 rows x 2 columns]

# %%
df.to_csv('../SingleCell-Files/organism_parts_ontology.csv', index=False, header=False, sep='\t')
