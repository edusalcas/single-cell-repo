# %%
import json

# %%
with open('../SingleCell-Files/raw_data/SCAE_projects.json') as f:
    SCAE_projects = json.load(f)

# %%
projects = SCAE_projects['experiments']

# %%
print(json.dumps(projects[0], indent=2, sort_keys=True))
# Out:
# {
#   "ArrayExpress_ID": null,
#   "ENA_ID": "SRP063840",
#   "downloads": [
#     {
#       "files": [
#         {
#           "description": "Experiment metadata (SDRF and IDF files archive)",
#           "isDownload": true,
#           "type": "icon-tsv",
#           "url": "experiment/E-CURD-10/download/zip?fileType=experiment-metadata&accessKey="
#         },
#         {
#           "description": "Experiment design file (TSV format)",
#           "isDownload": true,
#           "type": "icon-experiment-design",
#           "url": "experiment/E-CURD-10/download?fileType=experiment-design&accessKey="
#         }
#       ],
#       "title": "Metadata files"
#     },
#     {
#       "files": [
#         {
#           "description": "Clustering file (TSV format)",
#           "isDownload": true,
#           "type": "icon-tsv",
#           "url": "experiment/E-CURD-10/download?fileType=cluster&accessKey="
#         },
#         {
#           "description": "Filtered TPMs files (MatrixMarket archive)",
#           "isDownload": true,
#           "type": "icon-tsv",
#           "url": "experiment/E-CURD-10/download/zip?fileType=quantification-filtered&accessKey="
#         },
#         {
#           "description": "Marker gene files (TSV files archive)",
#           "isDownload": true,
#           "type": "icon-tsv",
#           "url": "experiment/E-CURD-10/download/zip?fileType=marker-genes&accessKey="
#         },
#         {
#           "description": "Normalised counts files (MatrixMarket archive)",
#           "isDownload": true,
#           "type": "icon-tsv",
#           "url": "experiment/E-CURD-10/download/zip?fileType=normalised&accessKey="
#         },
#         {
#           "description": "Raw counts files (MatrixMarket archive)",
#           "isDownload": true,
#           "type": "icon-tsv",
#           "url": "experiment/E-CURD-10/download/zip?fileType=quantification-raw&accessKey="
#         }
#       ],
#       "title": "Result files"
#     }
#   ],
#   "experimentAccession": "E-CURD-10",
#   "experimentDescription": "Single-cell transcriptome profiling for metastatic renal cell carcinoma patient-derived cells and xenografts",
#   "experimentProjects": [],
#   "experimentType": "Baseline",
#   "experimentalFactors": [
#     "single cell identifier",
#     "growth condition"
#   ],
#   "kingdom": "animals",
#   "lastUpdate": "25-09-2019",
#   "loadDate": "25-09-2019",
#   "numberOfAssays": 118,
#   "publication_link": [
#     "https://europepmc.org/abstract/MED/27139883"
#   ],
#   "publication_title": [
#     "Application of single-cell RNA sequencing in optimizing a combinatorial therapeutic strategy in metastatic renal cell carcinoma."
#   ],
#   "rawExperimentType": "SINGLE_CELL_RNASEQ_MRNA_BASELINE",
#   "repository_link": "https://www.ebi.ac.uk/gxa/sc/experiments/E-CURD-10/results/tsne",
#   "species": "Homo sapiens",
#   "supplementary_link": [
#     "https://www.ebi.ac.uk/ena/data/view/SRP063840"
#   ],
#   "technologyType": [
#     "smart-like"
#   ]
# }

# %%
experiment_accession = {}
experiment_description = {}
experiment_projects = {}
experiment_type = {}
experimental_factors = {}
kingdoms = {}
raw_experiment_type = {}
species = []
technology_types = []

# %%
for project in projects:
    technology_types += project['technologyType']
    species.append(project['species'])

# %%
species = set(species)
print(species)
# Out:
# {'Mus Musculus', 'Anopheles gambiae', 'Schistosoma mansoni', 'Homo sapiens', 'Danio rerio', 'Mus musculus', 'Rattus norvegicus', 'Callithrix jacchus', 'Gallus gallus', 'Caenorhabditis elegans', 'Drosophila melanogaster', 'Saccharomyces cerevisiae', 'Arabidopsis thaliana', 'Plasmodium berghei', 'Plasmodium falciparum 3D7'}

# %%
technology_types = set(technology_types)
print(technology_types)
# Out:
# {'smart-seq2', 'seq-well', '10xv2', '10xv3', 'smart-like', 'smart-seq', 'drop-seq'}

# %% [markdown]
# # Samples

# %%
with open('../SingleCell-Files/raw_data/SCAE_samples.json') as f:
    SCAE_samples = json.load(f)

# %%
print(json.dumps(SCAE_samples['specimens'][0], indent=2, sort_keys=True))
# Out:
# {
#   "accessKey": "",
#   "disclaimer": "",
#   "experimentAccession": "E-CURD-10",
#   "species": "homo sapiens",
#   "tabs": [
#     {
#       "name": "Results",
#       "props": {
#         "ks": [
#           2,
#           3,
#           4,
#           20,
#           37,
#           50
#         ],
#         "ksWithMarkerGenes": [
#           2,
#           3,
#           4
#         ],
#         "metadata": [
#           {
#             "label": "Growth condition",
#             "value": "growth_condition"
#           }
#         ],
#         "perplexities": [
#           10,
#           35,
#           1,
#           25,
#           45,
#           5,
#           30,
#           15,
#           50,
#           40,
#           20
#         ],
#         "selectedK": 3,
#         "suggesterEndpoint": "json/suggestions",
#         "units": [
#           "CPM"
#         ]
#       },
#       "type": "results"
#     },
#     {
#       "name": "Experiment Design",
#       "props": {
#         "downloadUrl": "experiment/E-CURD-10/download?fileType=experiment-design&accessKey=",
#         "table": {
#           "data": [
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431344"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_01",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431345"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_03",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431346"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_04",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431347"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_05",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431348"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_06",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431349"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_08",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431350"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_12",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431351"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_14",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431352"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_15",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431353"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_20",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431354"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_21",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431355"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_34",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431356"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_41",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431357"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_44",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431358"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_52",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431359"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_56",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431360"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_60",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431361"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_61",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431362"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_63",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431363"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_64",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431364"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_68",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431365"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_69",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431366"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_70",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431367"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_77",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431368"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_79",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431369"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_80",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431370"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_81",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431371"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_86",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431372"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_87",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431373"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_88",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431374"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_89",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431375"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_90",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431376"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_92",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431377"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_93",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431378"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_94",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431379"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_mRCC_SC_95",
#                   "patient-derived mouse xenograft from mixed primary and metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431381"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_03",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431382"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_05",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431383"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_06",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431384"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_10",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431385"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_13",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431386"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_14",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431387"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_16",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431388"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_24",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431389"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_27",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431390"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_28",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431391"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_29",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431392"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_34",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431393"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_35",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431394"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_36",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431395"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_37",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431396"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_46",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431397"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_49",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431398"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_50",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431399"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
#                   "not applicable",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "PDX_pRCC_SC_51",
#                   "biopsy from primary neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431400"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from primary neoplasm",
#                   "kidney",
# ...
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_81",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431456"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_84",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431457"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_85",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431458"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_86",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431459"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_87",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431460"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_88",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431461"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_90",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431462"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_92",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             },
#             {
#               "properties": {
#                 "analysed": true
#               },
#               "values": [
#                 [
#                   "SRR2431463"
#                 ],
#                 [
#                   "Homo sapiens",
#                   "43 year",
#                   "adult",
#                   "male",
#                   "biopsy from metastatic neoplasm",
#                   "kidney",
#                   "lung",
#                   "neoplasm",
#                   "renal cell carcinoma",
#                   "tumor refractory to pazopanib, everolimus and high-dose interleukin-2",
#                   "OK"
#                 ],
#                 [
#                   "Pt_mRCC_SC_93",
#                   "biopsy from metastatic neoplasm"
#                 ]
#               ]
#             }
#           ],
#           "headers": [
#             {
#               "name": "",
#               "values": [
#                 "Assay"
#               ]
#             },
#             {
#               "name": "Sample Characteristics",
#               "values": [
#                 "organism",
#                 "age",
#                 "developmental stage",
#                 "sex",
#                 "growth condition",
#                 "organism part",
#                 "metastatic site",
#                 "sampling site",
#                 "disease",
#                 "clinical history",
#                 "single cell quality"
#               ]
#             },
#             {
#               "name": "Experimental Variables",
#               "values": [
#                 "single cell identifier",
#                 "growth condition"
#               ]
#             }
#           ]
#         }
#       },
#       "type": "experiment-design"
#     },
#     {
#       "name": "Supplementary Information",
#       "props": {
#         "sections": [
#           {
#             "name": "Analysis Methods",
#             "props": {
#               "data": [
#                 [
#                   "Analysis",
#                   "Software",
#                   "Version",
#                   "Citation"
#                 ],
#                 [
#                   "filter_cells",
#                   "Scanpy FilterCells",
#                   "1.4.3+galaxy1",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_cells/8e48fa9618c1"
#                 ],
#                 [
#                   "filter_genes",
#                   "Scanpy FilterGenes",
#                   "1.4.3+galaxy3",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_genes/fa6c08064fc1"
#                 ],
#                 [
#                   "Filtering and trimming",
#                   "fastq_utils",
#                   "0.18.2",
#                   "https://github.com/nunofonseca/fastq_utils"
#                 ],
#                 [
#                   "Filtering and trimming",
#                   "FASTX-Toolkit",
#                   "0.0.14",
#                   "http://hannonlab.cshl.edu/fastx_toolkit/"
#                 ],
#                 [
#                   "find_clusters",
#                   "Scanpy FindCluster",
#                   "1.4.3+galaxy1",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_cluster/455846afcc73"
#                 ],
#                 [
#                   "find_markers",
#                   "Scanpy FindMarkers",
#                   "1.4.3+galaxy1",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_markers/c18f446dcfbf"
#                 ],
#                 [
#                   "find_variable_genes",
#                   "Scanpy FindVariableGenes",
#                   "1.4.3+galaxy9",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_variable_genes/7a68f44c866b"
#                 ],
#                 [
#                   "Gene/transcript quantification",
#                   "kallisto",
#                   "0.45.0",
#                   "Nicolas L Bray, Harold Pimentel, P\u00e1ll Melsted, Lior Pachter. Near-optimal probabilistic RNA-seq quantification. Nature Biotechnology (2016)."
#                 ],
#                 [
#                   "GTF2GeneList",
#                   "GTF2GeneList",
#                   "1.42.1+galaxy4",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/gtf2gene_list/b6354c917ef9"
#                 ],
#                 [
#                   "neighbours for umap",
#                   "Scanpy ComputeGraph",
#                   "1.4.3+galaxy11",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/232937b5bb8f"
#                 ],
#                 [
#                   "neighbours",
#                   "Scanpy ComputeGraph",
#                   "1.4.3+galaxy0",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/6b2673e1f4c6"
#                 ],
#                 [
#                   "n_neighbors",
#                   "Scanpy ParameterIterator",
#                   "0.0.1+galaxy2",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/7c4d44c14ceb"
#                 ],
#                 [
#                   "normalise_data",
#                   "Scanpy NormaliseData",
#                   "1.4.3+galaxy3",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_normalise_data/f7322b68cc90"
#                 ],
#                 [
#                   "Pipeline",
#                   "Gene expression group single-cell analysis pipeline (Nextflow)",
#                   "20.04.1",
#                   "https://github.com/ebi-gene-expression-group/scxa-control-workflow"
#                 ],
#                 [
#                   "plot_pca",
#                   "Scanpy PlotEmbed",
#                   "1.4.3+galaxy0",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_plot_embed/882f4671d686"
#                 ],
#                 [
#                   "QC",
#                   "FastQC",
#                   "0.11.8",
#                   "http://www.bioinformatics.babraham.ac.uk/projects/fastqc/"
#                 ],
#                 [
#                   "Reference",
#                   "Ensembl",
#                   "99",
#                   "Homo_sapiens.GRCh38.cdna.all.99.fa.gz, Homo_sapiens.GRCh38.99.gtf.gz"
#                 ],
#                 [
#                   "resolution",
#                   "Scanpy ParameterIterator",
#                   "0.0.1+galaxy1",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/f0dd61087af3"
#                 ],
#                 [
#                   "run_pca",
#                   "Scanpy RunPCA",
#                   "1.4.3+galaxy10",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_pca/2dd53b944e78"
#                 ],
#                 [
#                   "run_tsne",
#                   "Scanpy RunTSNE",
#                   "1.4.3+galaxy1",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_tsne/3589dfaef3f6"
#                 ],
#                 [
#                   "run_umap",
#                   "Scanpy RunUMAP",
#                   "1.4.3+galaxy1",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_umap/c111d7d04f0b"
#                 ],
#                 [
#                   "Scanpy Read10x",
#                   "Scanpy Read10x",
#                   "1.4.3+galaxy0",
#                   "https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_read_10x/cf55e0e462da"
#                 ],
#                 [
#                   "Configuration",
#                   "scxa-workflows",
#                   "db1eeaf",
#                   "https://github.com/ebi-gene-expression-group/scxa-workflows"
#                 ]
#               ]
#             },
#             "type": "static-table"
#           },
#           {
#             "name": "Resources",
#             "props": {
#               "url": "json/experiments/E-CURD-10/resources/SUPPLEMENTARY_INFORMATION"
#             },
#             "type": "resources"
#           }
#         ]
#       },
#       "type": "supplementary-information"
#     },
#     {
#       "name": "Downloads",
#       "props": {
#         "data": [
#           {
#             "files": [
#               {
#                 "description": "Experiment metadata (SDRF and IDF files archive)",
#                 "isDownload": true,
#                 "type": "icon-tsv",
#                 "url": "experiment/E-CURD-10/download/zip?fileType=experiment-metadata&accessKey="
#               },
#               {
#                 "description": "Experiment design file (TSV format)",
#                 "isDownload": true,
#                 "type": "icon-experiment-design",
#                 "url": "experiment/E-CURD-10/download?fileType=experiment-design&accessKey="
#               }
#             ],
#             "title": "Metadata files"
#           },
#           {
#             "files": [
#               {
#                 "description": "Clustering file (TSV format)",
#                 "isDownload": true,
#                 "type": "icon-tsv",
#                 "url": "experiment/E-CURD-10/download?fileType=cluster&accessKey="
#               },
#               {
#                 "description": "Filtered TPMs files (MatrixMarket archive)",
#                 "isDownload": true,
#                 "type": "icon-tsv",
#                 "url": "experiment/E-CURD-10/download/zip?fileType=quantification-filtered&accessKey="
#               },
#               {
#                 "description": "Marker gene files (TSV files archive)",
#                 "isDownload": true,
#                 "type": "icon-tsv",
#                 "url": "experiment/E-CURD-10/download/zip?fileType=marker-genes&accessKey="
#               },
#               {
#                 "description": "Normalised counts files (MatrixMarket archive)",
#                 "isDownload": true,
#                 "type": "icon-tsv",
#                 "url": "experiment/E-CURD-10/download/zip?fileType=normalised&accessKey="
#               },
#               {
#                 "description": "Raw counts files (MatrixMarket archive)",
#                 "isDownload": true,
#                 "type": "icon-tsv",
#                 "url": "experiment/E-CURD-10/download/zip?fileType=quantification-raw&accessKey="
#               }
#             ],
#             "title": "Result files"
#           }
#         ]
#       },
#       "type": "downloads"
#     }
#   ]
# }

# %%
samples = SCAE_samples['specimens']

# %%
len(samples)
# Out:
# 153

# %% [markdown]
# ## Downloads

# %%
import pprint
data_format = {}

for sample in samples:
    samples_data = sample['tabs'][3]['props']['data']
    for sample_data in samples_data:
        titulo = sample_data['title']
        
        if titulo not in data_format.keys():
            data_format[titulo] = set()
        
        files = sample_data['files']
        
        for file in files:
            if file['isDownload']:
                data_format[titulo].add(file['description'])

pprint.pprint(data_format)
# Out:
# {'Metadata files': {'Experiment design file (TSV format)',
#                     'Experiment metadata (SDRF and IDF files archive)'},
#  'Result files': {'Clustering file (TSV format)',
#                   'Filtered TPMs files (MatrixMarket archive)',
#                   'Marker gene files (TSV files archive)',
#                   'Normalised counts files (MatrixMarket archive)',
#                   'Raw counts files (MatrixMarket archive)'}}

# %% [markdown]
# ## Experiment design

# %% [markdown]
# Headers

# %%
import pprint

headers = {
    'sample_characteristics': set(),
    'experimental_variables': set()
}

len_headers = set()

for sample in samples:
    sample_headers = sample['tabs'][1]['props']['table']['headers']
    
    for sample_header in sample_headers:
        if sample_header['name'] == 'Sample Characteristics':
            headers['sample_characteristics'] |= set(sample_header['values'])
        elif sample_header['name'] == 'Experimental Variables':
            headers['experimental_variables'] |= set(sample_header['values'])
    
pprint.pprint(headers)
# Out:
# {'experimental_variables': {'age',
#                             'biopsy site',
#                             'block',
#                             'cell cycle phase',
#                             'cell line',
#                             'cell type',
#                             'clinical history',
#                             'clinical information',
#                             'compound',
#                             'developmental stage',
#                             'disease',
#                             'dose',
#                             'environmental stress',
#                             'facs sorting',
#                             'fraction',
#                             'genotype',
#                             'growth condition',
#                             'histology',
#                             'immunophenotype',
#                             'individual',
#                             'infect',
#                             'infection',
#                             'inferred cell type - authors labels',
#                             'inferred cell type - ontology labels',
#                             'inferred developmental stage',
#                             'inferred sex',
#                             'injury',
#                             'metastatic site',
#                             'organism part',
#                             'passage',
#                             'phenotype',
#                             'progenitor cell type',
#                             'protocol',
#                             'replicate',
#                             'response to treatment',
#                             'sampling site',
#                             'sampling time point',
#                             'sex',
#                             'single cell identifier',
#                             'stimulus',
#                             'strain',
#                             'temperature',
#                             'time'},
#  'sample_characteristics': {'age',
#                             'ancestry category',
#                             'biomaterial_provider',
#                             'biopsy site',
#                             'biosource provider',
#                             'block',
#                             'bmi',
#                             'body mass index',
#                             'breed',
#                             'cause of death',
#                             'cell cycle phase',
#                             'cell line',
#                             'cell type',
#                             'clinical history',
#                             'clinical information',
#                             'cluster',
#                             'date',
#                             'developmental stage',
#                             'disease',
#                             'disease staging',
#                             'ecotype',
#                             'ethnic group',
#                             'facs marker',
#                             'facs sorting',
#                             'fluidigm c1 run',
#                             'forward scatter',
#                             'fraction',
#                             'genotype',
#                             'gfp fluorescence',
#                             'growth condition',
#                             'histology',
#                             'hoo inferred timepoint',
#                             'immunophenotype',
#                             'individual',
#                             'infect',
#                             'infection',
#                             'inferred cell subtype',
#                             'inferred cell type - authors labels',
#                             'inferred cell type - ontology labels',
#                             'inferred developmental stage',
#                             'inferred disease subtype',
#                             'inferred identity',
#                             'inferred non-neural cell type',
#                             'inferred sex',
#                             'karyotype',
#                             'lasonder inferred developmental stage',
#                             'lopez inferred developmental stage',
#                             'metastatic site',
#                             'microwell plate',
#                             'organism',
#                             'organism part',
#                             'organism status',
#                             'otto inferred developmental stage',
#                             'otto inferred timepoint',
#                             'passage',
#                             'phenotype',
#                             'pi fluorescence',
#                             'plate',
#                             'post analysis well quality',
#                             'post conception age',
#                             'post-analysis well quality',
#                             'progenitor cell type',
#                             'protocol',
#                             'psuedotime inferred timepoint',
#                             'replicate',
#                             'reporter fluorescence',
#                             'response to treatment',
#                             'sampling site',
#                             'sampling time point',
#                             'sex',
#                             'side scatter',
#                             'single cell identifier',
#                             'single cell quality',
#                             'single cell well quality',
#                             'specimen with known storage state',
#                             'stimulus',
#                             'strain',
#                             'submitted single cell quality',
#                             'time',
#                             'tumor grading',
#                             'well',
#                             'well information'}}

# %%
def get_headers_dict_from_sample(sample):
    headers_aux = {
        'sample_characteristics': {},
        'experimental_variables': {}
    }

    header_order = {}
    header_types = {
        'sample_characteristics': [],
        'experimental_variables': []        
    }

    # Init dictionary and the header types for the sample
    sample_headers = sample['tabs'][1]['props']['table']['headers']
    sample_characteristics_headers = []
    experimental_variables_headers = []

    for n, sample_header in enumerate(sample_headers):
        if sample_header['name'] == 'Sample Characteristics':
            header_order['sample_characteristics'] = n
            for sample_characteristic in sample_header['values']:
                # If key has not been viewed yet, add it to dictionary
                if sample_characteristic not in headers_aux['sample_characteristics'].keys():
                    headers_aux['sample_characteristics'][sample_characteristic] = set()

                # Add the type of the header
                header_types['sample_characteristics'] += [sample_characteristic]
        elif sample_header['name'] == 'Experimental Variables':
            header_order['experimental_variables'] = n
            for experimental_variable in sample_header['values']:
                # If key has not been viewed yet, add it to dictionary
                if sample_characteristic not in headers_aux['experimental_variables'].keys():
                    headers_aux['experimental_variables'][sample_characteristic] = set()

                # Add the types of the header
                header_types['experimental_variables'] += [sample_characteristic]
                
    return headers_aux, header_types, header_order

# %%
def sample_to_dict(sample):
    # Get headers, initiating dict, headers types and the order of the headers
    dictionary, header_types, header_order = get_headers_dict_from_sample(sample)
    
    # Get sample data
    sample_data = sample['tabs'][1]['props']['table']['data']

    # For each cell in data
    for cell in sample_data:
        # For each header type
        for header_type in ['sample_characteristics', 'experimental_variables']:
            # Add the values to the dictionary
            values = cell['values'][header_order[header_type]]
            headers = header_types[header_type]
            for value, header_name in zip(values, headers):
                dictionary[header_type][header_name].add(value)
        
    return dictionary

# %%
sample_to_dict(samples[0])
# Out:
# {'sample_characteristics': {'organism': {'Homo sapiens'},
#   'age': {'43 year'},
#   'developmental stage': {'adult'},
#   'sex': {'male'},
#   'growth condition': {'biopsy from metastatic neoplasm',
#    'biopsy from primary neoplasm',
#    'patient-derived mouse xenograft from mixed primary and metastatic neoplasm'},
#   'organism part': {'kidney'},
#   'metastatic site': {'lung', 'not applicable'},
#   'sampling site': {'neoplasm'},
#   'disease': {'renal cell carcinoma'},
#   'clinical history': {'tumor refractory to pazopanib, everolimus and high-dose interleukin-2'},
#   'single cell quality': {'OK'}},
#  'experimental_variables': {'single cell quality': {'PDX_mRCC_SC_01',
#    'PDX_mRCC_SC_03',
#    'PDX_mRCC_SC_04',
#    'PDX_mRCC_SC_05',
#    'PDX_mRCC_SC_06',
#    'PDX_mRCC_SC_08',
#    'PDX_mRCC_SC_12',
#    'PDX_mRCC_SC_14',
#    'PDX_mRCC_SC_15',
#    'PDX_mRCC_SC_20',
#    'PDX_mRCC_SC_21',
#    'PDX_mRCC_SC_34',
#    'PDX_mRCC_SC_41',
#    'PDX_mRCC_SC_44',
#    'PDX_mRCC_SC_52',
#    'PDX_mRCC_SC_56',
#    'PDX_mRCC_SC_60',
#    'PDX_mRCC_SC_61',
#    'PDX_mRCC_SC_63',
#    'PDX_mRCC_SC_64',
#    'PDX_mRCC_SC_68',
#    'PDX_mRCC_SC_69',
#    'PDX_mRCC_SC_70',
#    'PDX_mRCC_SC_77',
#    'PDX_mRCC_SC_79',
#    'PDX_mRCC_SC_80',
#    'PDX_mRCC_SC_81',
#    'PDX_mRCC_SC_86',
#    'PDX_mRCC_SC_87',
#    'PDX_mRCC_SC_88',
#    'PDX_mRCC_SC_89',
#    'PDX_mRCC_SC_90',
#    'PDX_mRCC_SC_92',
#    'PDX_mRCC_SC_93',
#    'PDX_mRCC_SC_94',
#    'PDX_mRCC_SC_95',
#    'PDX_pRCC_SC_03',
#    'PDX_pRCC_SC_05',
#    'PDX_pRCC_SC_06',
#    'PDX_pRCC_SC_10',
#    'PDX_pRCC_SC_13',
#    'PDX_pRCC_SC_14',
#    'PDX_pRCC_SC_16',
#    'PDX_pRCC_SC_24',
#    'PDX_pRCC_SC_27',
#    'PDX_pRCC_SC_28',
#    'PDX_pRCC_SC_29',
#    'PDX_pRCC_SC_34',
#    'PDX_pRCC_SC_35',
#    'PDX_pRCC_SC_36',
#    'PDX_pRCC_SC_37',
#    'PDX_pRCC_SC_46',
#    'PDX_pRCC_SC_49',
#    'PDX_pRCC_SC_50',
#    'PDX_pRCC_SC_51',
#    'PDX_pRCC_SC_52',
#    'PDX_pRCC_SC_53',
#    'PDX_pRCC_SC_55',
#    'PDX_pRCC_SC_56',
#    'PDX_pRCC_SC_57',
#    'PDX_pRCC_SC_58',
#    'PDX_pRCC_SC_59',
#    'PDX_pRCC_SC_60',
#    'PDX_pRCC_SC_61',
#    'PDX_pRCC_SC_62',
#    'PDX_pRCC_SC_65',
#    'PDX_pRCC_SC_66',
#    'PDX_pRCC_SC_67',
#    'PDX_pRCC_SC_68',
#    'PDX_pRCC_SC_70',
#    'PDX_pRCC_SC_72',
#    'PDX_pRCC_SC_73',
#    'PDX_pRCC_SC_75',
#    'PDX_pRCC_SC_78',
#    'PDX_pRCC_SC_79',
#    'PDX_pRCC_SC_84',
#    'PDX_pRCC_SC_87',
#    'PDX_pRCC_SC_88',
#    'PDX_pRCC_SC_89',
#    'PDX_pRCC_SC_90',
#    'PDX_pRCC_SC_91',
#    'PDX_pRCC_SC_93',
#    'PDX_pRCC_SC_94',
#    'Pt_mRCC_SC_01',
#    'Pt_mRCC_SC_03',
#    'Pt_mRCC_SC_05',
#    'Pt_mRCC_SC_10',
#    'Pt_mRCC_SC_11',
#    'Pt_mRCC_SC_12',
#    'Pt_mRCC_SC_17',
#    'Pt_mRCC_SC_21',
#    'Pt_mRCC_SC_23',
#    'Pt_mRCC_SC_24',
#    'Pt_mRCC_SC_30',
#    'Pt_mRCC_SC_33',
#    'Pt_mRCC_SC_36',
#    'Pt_mRCC_SC_39',
#    'Pt_mRCC_SC_43',
#    'Pt_mRCC_SC_53',
#    'Pt_mRCC_SC_56',
#    'Pt_mRCC_SC_57',
#    'Pt_mRCC_SC_58',
#    'Pt_mRCC_SC_59',
#    'Pt_mRCC_SC_61',
#    'Pt_mRCC_SC_64',
#    'Pt_mRCC_SC_69',
#    'Pt_mRCC_SC_71',
#    'Pt_mRCC_SC_75',
#    'Pt_mRCC_SC_79',
#    'Pt_mRCC_SC_81',
#    'Pt_mRCC_SC_84',
#    'Pt_mRCC_SC_85',
#    'Pt_mRCC_SC_86',
#    'Pt_mRCC_SC_87',
#    'Pt_mRCC_SC_88',
#    'Pt_mRCC_SC_90',
#    'Pt_mRCC_SC_92',
#    'Pt_mRCC_SC_93',
#    'biopsy from metastatic neoplasm',
#    'biopsy from primary neoplasm',
#    'patient-derived mouse xenograft from mixed primary and metastatic neoplasm'}}}

# %%
def merge_dict(dict1, dict2):
    ''' Merge dictionaries and keep values of common keys in list'''
    dict3 = {}
    for key in dict1.keys():
        dict3[key] = {**dict1[key], **dict2[key]}
        
        for key2, value in dict3[key].items():
            if key2 in dict1[key] and key2 in dict2[key]:
                dict3[key][key2] |= dict1[key][key2]
    
    return dict3
# Out:
# {'a': {'f': {1, 2, 10, 11, 12}}, 'b': {'u': {10, 14, 15}, 'f': {11}}}

# %%
def process_dict(dictionary):
    for key in dictionary:
        for key2 in dictionary[key]:
            dictionary[key][key2] = list(dictionary[key][key2])
    return dictionary

# %%
dictionary_values = {
    'sample_characteristics': {},
    'experimental_variables': {}
}

for sample in samples:
    sample_dict = sample_to_dict(sample)
    
    dictionary_values = merge_dict(dictionary_values, sample_dict)

dictionary_values = process_dict(dictionary_values)

with open('../SingleCell-Files/values.json', 'w') as outfile:
    json.dump(dictionary_values, outfile)

# %%
headers_aux = {
    'sample_characteristics': {},
    'experimental_variables': {}
}


for sample in [samples[0]]:
    # Init dictionary and the header types for the sample
    sample_headers = sample['tabs'][1]['props']['table']['headers']
    header_types = []

    for sample_header in sample_headers:
        if sample_header['name'] == 'Sample Characteristics':
            for sample_characteristic in sample_header['values']:
                # If key has not been viewed yet, add it to dictionary
                if sample_characteristic not in headers_aux['sample_characteristics'].keys():
                    headers_aux['sample_characteristics'][sample_characteristic] = set()
                
            # Add the types of the header
            header_types += ['sample_characteristics'] * len(sample_header['values'])
        elif sample_header['name'] == 'Experimental Variables':
            for experimental_variable in sample_header['values']:
                # If key has not been viewed yet, add it to dictionary
                if sample_characteristic not in headers_aux['experimental_variables'].keys():
                    headers_aux['experimental_variables'][sample_characteristic] = set()
            
            # Add the types of the header
            header_types += ['experimental_variables'] * len(sample_header['values'])    
    
    # Read the experiment data from the sample
    sample_data = sample['tabs'][1]['props']['table']['data']
    
    
pprint.pprint(headers_aux)
pprint.pprint(header_types)
# Out:
# {'experimental_variables': {'single cell quality': set()},
#  'sample_characteristics': {'age': set(),
#                             'clinical history': set(),
#                             'developmental stage': set(),
#                             'disease': set(),
#                             'growth condition': set(),
#                             'metastatic site': set(),
#                             'organism': set(),
#                             'organism part': set(),
#                             'sampling site': set(),
#                             'sex': set(),
#                             'single cell quality': set()}}
# ['sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'sample_characteristics',
#  'experimental_variables',
#  'experimental_variables']

# %%
import re
import requests
from lxml import html

def get_info_from_html(experiment_ID):
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"
    headers = {
        "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
    }
    # Get the project samples information
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
       # accessing_error.append(answer)
        clear_output(wait=True)
        return None
    
    # Parse response so we get the sample information
    parser = html.fromstring(answer.text)
    script_text = parser.xpath(".//div[@id='content']//script[3]/text()") 
    match = re.search(r'content: (?P<value>{.*})', script_text[0])
    value = match.group('value')
    
    return value

# %%
sample = get_info_from_html('E-CURD-10')
sample
# Out:
# '{"experimentAccession":"E-CURD-10","accessKey":"","species":"homo sapiens","disclaimer":"","tabs":[{"type":"results","name":"Results","props":{"ks":[2,3,4,20,37,50],"ksWithMarkerGenes":[2,3,4],"selectedK":3,"perplexities":[10,35,1,25,45,5,30,15,50,40,20],"metadata":[{"value":"growth_condition","label":"Growth condition"}],"units":["CPM"],"suggesterEndpoint":"json/suggestions"}},{"type":"experiment-design","name":"Experiment Design","props":{"table":{"headers":[{"name":"","values":["Assay"]},{"name":"Sample Characteristics","values":["organism","age","developmental stage","sex","growth condition","organism part","metastatic site","sampling site","disease","clinical history","single cell quality"]},{"name":"Experimental Variables","values":["single cell identifier","growth condition"]}],"data":[{"properties":{"analysed":true},"values":[["SRR2431344"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_01","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431345"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_03","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431346"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_04","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431347"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_05","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431348"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_06","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431349"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_08","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431350"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_12","patient-derived mouse xenograft from mixed primary and metastatic neoplasm"]]},{"properties":{"analysed":true},"values":[["SRR2431351"],["Homo sapiens","43 year","adult","male","patient-derived mouse xenograft from mixed primary and metastatic neoplasm","kidney","lung","neoplasm","renal cell carcinoma","tumor refractory to pazopanib, everolimus and high-dose interleukin-2","OK"],["PDX_mRCC_SC_14","patient-derived mouse xenograft from mixed primary and metastatic  ...

# %%
json.loads(sample)
# Out:
# {'experimentAccession': 'E-CURD-10',
#  'accessKey': '',
#  'species': 'homo sapiens',
#  'disclaimer': '',
#  'tabs': [{'type': 'results',
#    'name': 'Results',
#    'props': {'ks': [2, 3, 4, 20, 37, 50],
#     'ksWithMarkerGenes': [2, 3, 4],
#     'selectedK': 3,
#     'perplexities': [10, 35, 1, 25, 45, 5, 30, 15, 50, 40, 20],
#     'metadata': [{'value': 'growth_condition', 'label': 'Growth condition'}],
#     'units': ['CPM'],
#     'suggesterEndpoint': 'json/suggestions'}},
#   {'type': 'experiment-design',
#    'name': 'Experiment Design',
#    'props': {'table': {'headers': [{'name': '', 'values': ['Assay']},
#       {'name': 'Sample Characteristics',
#        'values': ['organism',
#         'age',
#         'developmental stage',
#         'sex',
#         'growth condition',
#         'organism part',
#         'metastatic site',
#         'sampling site',
#         'disease',
#         'clinical history',
#         'single cell quality']},
#       {'name': 'Experimental Variables',
#        'values': ['single cell identifier', 'growth condition']}],
#      'data': [{'properties': {'analysed': True},
#        'values': [['SRR2431344'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_01',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431345'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_03',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431346'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_04',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431347'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_05',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431348'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_06',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431349'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_08',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431350'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_12',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431351'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_14',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431352'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_15',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431353'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_20',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431354'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_21',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431355'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_34',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431356'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_41',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431357'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_44',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431358'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_52',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431359'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_56',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431360'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_60',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431361'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_61',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431362'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_63',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431363'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_64',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431364'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_68',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431365'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_69',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431366'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_70',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431367'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_77',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431368'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_79',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431369'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_80',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431370'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_81',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431371'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_86',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431372'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_87',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431373'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_88',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431374'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_89',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431375'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_90',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431376'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_92',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431377'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_93',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431378'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_94',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431379'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_95',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431381'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_03', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431382'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_05', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431383'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_06', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431384'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_10', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431385'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_13', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431386'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_14', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431387'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_16', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431388'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_24', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431389'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_27', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431390'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_28', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431391'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_29', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431392'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_34', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431393'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_35', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431394'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_36', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431395'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_37', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431396'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_46', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431397'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_49', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431398'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_50', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431399'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_51', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431400'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_52', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431401'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_53', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431402'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_55', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431403'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_56', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431404'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_57', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431405'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_58', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431406'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_59', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431407'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_60', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431408'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_61', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431409'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_62', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431410'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_65', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431411'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_66', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431412'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_67', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431413'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_68', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431414'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_70', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431415'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_72', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431416'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_73', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431417'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_75', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431418'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_78', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431419'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_79', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431420'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_84', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431421'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_87', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431422'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_88', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431423'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_89', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431424'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_90', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431425'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_91', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431426'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_93', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431427'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_94', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431429'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_01', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431430'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_03', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431431'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_05', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431432'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_10', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431433'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_11', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431434'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_12', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431435'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_17', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431436'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_21', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431437'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_23', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431438'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_24', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431439'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_30', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431440'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_33', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431441'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_36', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431442'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_39', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431443'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_43', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431444'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_53', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431445'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_56', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431446'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_57', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431447'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_58', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431448'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_59', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431449'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_61', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431450'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_64', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431451'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_69', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431452'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_71', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431453'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_75', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431454'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_79', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431455'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_81', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431456'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_84', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431457'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_85', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431458'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_86', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431459'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_87', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431460'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_88', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431461'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_90', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431462'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_92', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431463'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_93', 'biopsy from metastatic neoplasm']]}]},
#     'downloadUrl': 'experiment/E-CURD-10/download?fileType=experiment-design&accessKey='}},
#   {'type': 'supplementary-information',
#    'name': 'Supplementary Information',
#    'props': {'sections': [{'type': 'static-table',
#       'name': 'Analysis Methods',
#       'props': {'data': [['Analysis', 'Software', 'Version', 'Citation'],
#         ['filter_cells',
#          'Scanpy FilterCells',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_cells/8e48fa9618c1'],
#         ['filter_genes',
#          'Scanpy FilterGenes',
#          '1.4.3+galaxy3',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_genes/fa6c08064fc1'],
#         ['Filtering and trimming',
#          'fastq_utils',
#          '0.18.2',
#          'https://github.com/nunofonseca/fastq_utils'],
#         ['Filtering and trimming',
#          'FASTX-Toolkit',
#          '0.0.14',
#          'http://hannonlab.cshl.edu/fastx_toolkit/'],
#         ['find_clusters',
#          'Scanpy FindCluster',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_cluster/455846afcc73'],
#         ['find_markers',
#          'Scanpy FindMarkers',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_markers/c18f446dcfbf'],
#         ['find_variable_genes',
#          'Scanpy FindVariableGenes',
#          '1.4.3+galaxy9',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_variable_genes/7a68f44c866b'],
#         ['Gene/transcript quantification',
#          'kallisto',
#          '0.45.0',
#          'Nicolas L Bray, Harold Pimentel, Páll Melsted, Lior Pachter. Near-optimal probabilistic RNA-seq quantification. Nature Biotechnology (2016).'],
#         ['GTF2GeneList',
#          'GTF2GeneList',
#          '1.42.1+galaxy4',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/gtf2gene_list/b6354c917ef9'],
#         ['neighbours for umap',
#          'Scanpy ComputeGraph',
#          '1.4.3+galaxy11',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/232937b5bb8f'],
#         ['neighbours',
#          'Scanpy ComputeGraph',
#          '1.4.3+galaxy0',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/6b2673e1f4c6'],
#         ['n_neighbors',
#          'Scanpy ParameterIterator',
#          '0.0.1+galaxy2',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/7c4d44c14ceb'],
#         ['normalise_data',
#          'Scanpy NormaliseData',
#          '1.4.3+galaxy3',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_normalise_data/f7322b68cc90'],
#         ['Pipeline',
#          'Gene expression group single-cell analysis pipeline (Nextflow)',
#          '20.04.1',
#          'https://github.com/ebi-gene-expression-group/scxa-control-workflow'],
#         ['plot_pca',
#          'Scanpy PlotEmbed',
#          '1.4.3+galaxy0',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_plot_embed/882f4671d686'],
#         ['QC',
#          'FastQC',
#          '0.11.8',
#          'http://www.bioinformatics.babraham.ac.uk/projects/fastqc/'],
#         ['Reference',
#          'Ensembl',
#          '99',
#          'Homo_sapiens.GRCh38.cdna.all.99.fa.gz, Homo_sapiens.GRCh38.99.gtf.gz'],
#         ['resolution',
#          'Scanpy ParameterIterator',
#          '0.0.1+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/f0dd61087af3'],
#         ['run_pca',
#          'Scanpy RunPCA',
#          '1.4.3+galaxy10',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_pca/2dd53b944e78'],
#         ['run_tsne',
#          'Scanpy RunTSNE',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_tsne/3589dfaef3f6'],
#         ['run_umap',
#          'Scanpy RunUMAP',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_umap/c111d7d04f0b'],
#         ['Scanpy Read10x',
#          'Scanpy Read10x',
#          '1.4.3+galaxy0',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_read_10x/cf55e0e462da'],
#         ['Configuration',
#          'scxa-workflows',
#          'db1eeaf',
#          'https://github.com/ebi-gene-expression-group/scxa-workflows']]}},
#      {'type': 'resources',
#       'name': 'Resources',
#       'props': {'url': 'json/experiments/E-CURD-10/resources/SUPPLEMENTARY_INFORMATION'}}]}},
#   {'type': 'downloads',
#    'name': 'Downloads',
#    'props': {'data': [{'title': 'Metadata files',
#       'files': [{'url': 'experiment/E-CURD-10/download/zip?fileType=experiment-metadata&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Experiment metadata (SDRF and IDF files archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download?fileType=experiment-design&accessKey=',
#         'type': 'icon-experiment-design',
#         'description': 'Experiment design file (TSV format)',
#         'isDownload': True}]},
#      {'title': 'Result files',
#       'files': [{'url': 'experiment/E-CURD-10/download?fileType=cluster&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Clustering file (TSV format)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=quantification-filtered&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Filtered TPMs files (MatrixMarket archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=marker-genes&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Marker gene files (TSV files archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=normalised&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Normalised counts files (MatrixMarket archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=quantification-raw&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Raw counts files (MatrixMarket archive)',
#         'isDownload': True}]}]}}]}

# %% [markdown]
# # Check if a donor has diferent values

# %%
samples[0]
# Out:
# {'experimentAccession': 'E-CURD-10',
#  'accessKey': '',
#  'species': 'homo sapiens',
#  'disclaimer': '',
#  'tabs': [{'type': 'results',
#    'name': 'Results',
#    'props': {'ks': [2, 3, 4, 20, 37, 50],
#     'ksWithMarkerGenes': [2, 3, 4],
#     'selectedK': 3,
#     'perplexities': [10, 35, 1, 25, 45, 5, 30, 15, 50, 40, 20],
#     'metadata': [{'value': 'growth_condition', 'label': 'Growth condition'}],
#     'units': ['CPM'],
#     'suggesterEndpoint': 'json/suggestions'}},
#   {'type': 'experiment-design',
#    'name': 'Experiment Design',
#    'props': {'table': {'headers': [{'name': '', 'values': ['Assay']},
#       {'name': 'Sample Characteristics',
#        'values': ['organism',
#         'age',
#         'developmental stage',
#         'sex',
#         'growth condition',
#         'organism part',
#         'metastatic site',
#         'sampling site',
#         'disease',
#         'clinical history',
#         'single cell quality']},
#       {'name': 'Experimental Variables',
#        'values': ['single cell identifier', 'growth condition']}],
#      'data': [{'properties': {'analysed': True},
#        'values': [['SRR2431344'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_01',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431345'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_03',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431346'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_04',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431347'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_05',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431348'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_06',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431349'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_08',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431350'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_12',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431351'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_14',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431352'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_15',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431353'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_20',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431354'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_21',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431355'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_34',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431356'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_41',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431357'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_44',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431358'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_52',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431359'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_56',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431360'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_60',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431361'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_61',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431362'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_63',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431363'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_64',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431364'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_68',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431365'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_69',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431366'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_70',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431367'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_77',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431368'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_79',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431369'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_80',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431370'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_81',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431371'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_86',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431372'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_87',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431373'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_88',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431374'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_89',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431375'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_90',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431376'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_92',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431377'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_93',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431378'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_94',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431379'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_mRCC_SC_95',
#          'patient-derived mouse xenograft from mixed primary and metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431381'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_03', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431382'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_05', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431383'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_06', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431384'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_10', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431385'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_13', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431386'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_14', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431387'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_16', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431388'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_24', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431389'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_27', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431390'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_28', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431391'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_29', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431392'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_34', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431393'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_35', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431394'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_36', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431395'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_37', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431396'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_46', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431397'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_49', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431398'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_50', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431399'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_51', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431400'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_52', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431401'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_53', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431402'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_55', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431403'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_56', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431404'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_57', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431405'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_58', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431406'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_59', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431407'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_60', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431408'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_61', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431409'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_62', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431410'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_65', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431411'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_66', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431412'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_67', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431413'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_68', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431414'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_70', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431415'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_72', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431416'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_73', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431417'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_75', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431418'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_78', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431419'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_79', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431420'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_84', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431421'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_87', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431422'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_88', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431423'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_89', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431424'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_90', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431425'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_91', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431426'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_93', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431427'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from primary neoplasm',
#          'kidney',
#          'not applicable',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['PDX_pRCC_SC_94', 'biopsy from primary neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431429'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_01', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431430'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_03', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431431'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_05', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431432'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_10', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431433'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_11', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431434'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_12', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431435'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_17', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431436'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_21', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431437'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_23', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431438'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_24', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431439'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_30', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431440'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_33', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431441'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_36', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431442'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_39', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431443'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_43', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431444'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_53', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431445'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_56', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431446'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_57', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431447'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_58', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431448'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_59', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431449'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_61', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431450'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_64', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431451'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_69', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431452'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_71', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431453'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_75', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431454'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_79', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431455'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_81', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431456'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_84', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431457'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_85', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431458'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_86', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431459'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_87', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431460'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_88', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431461'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_90', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431462'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_92', 'biopsy from metastatic neoplasm']]},
#       {'properties': {'analysed': True},
#        'values': [['SRR2431463'],
#         ['Homo sapiens',
#          '43 year',
#          'adult',
#          'male',
#          'biopsy from metastatic neoplasm',
#          'kidney',
#          'lung',
#          'neoplasm',
#          'renal cell carcinoma',
#          'tumor refractory to pazopanib, everolimus and high-dose interleukin-2',
#          'OK'],
#         ['Pt_mRCC_SC_93', 'biopsy from metastatic neoplasm']]}]},
#     'downloadUrl': 'experiment/E-CURD-10/download?fileType=experiment-design&accessKey='}},
#   {'type': 'supplementary-information',
#    'name': 'Supplementary Information',
#    'props': {'sections': [{'type': 'static-table',
#       'name': 'Analysis Methods',
#       'props': {'data': [['Analysis', 'Software', 'Version', 'Citation'],
#         ['filter_cells',
#          'Scanpy FilterCells',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_cells/8e48fa9618c1'],
#         ['filter_genes',
#          'Scanpy FilterGenes',
#          '1.4.3+galaxy3',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_genes/fa6c08064fc1'],
#         ['Filtering and trimming',
#          'fastq_utils',
#          '0.18.2',
#          'https://github.com/nunofonseca/fastq_utils'],
#         ['Filtering and trimming',
#          'FASTX-Toolkit',
#          '0.0.14',
#          'http://hannonlab.cshl.edu/fastx_toolkit/'],
#         ['find_clusters',
#          'Scanpy FindCluster',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_cluster/455846afcc73'],
#         ['find_markers',
#          'Scanpy FindMarkers',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_markers/c18f446dcfbf'],
#         ['find_variable_genes',
#          'Scanpy FindVariableGenes',
#          '1.4.3+galaxy9',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_variable_genes/7a68f44c866b'],
#         ['Gene/transcript quantification',
#          'kallisto',
#          '0.45.0',
#          'Nicolas L Bray, Harold Pimentel, Páll Melsted, Lior Pachter. Near-optimal probabilistic RNA-seq quantification. Nature Biotechnology (2016).'],
#         ['GTF2GeneList',
#          'GTF2GeneList',
#          '1.42.1+galaxy4',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/gtf2gene_list/b6354c917ef9'],
#         ['neighbours for umap',
#          'Scanpy ComputeGraph',
#          '1.4.3+galaxy11',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/232937b5bb8f'],
#         ['neighbours',
#          'Scanpy ComputeGraph',
#          '1.4.3+galaxy0',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/6b2673e1f4c6'],
#         ['n_neighbors',
#          'Scanpy ParameterIterator',
#          '0.0.1+galaxy2',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/7c4d44c14ceb'],
#         ['normalise_data',
#          'Scanpy NormaliseData',
#          '1.4.3+galaxy3',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_normalise_data/f7322b68cc90'],
#         ['Pipeline',
#          'Gene expression group single-cell analysis pipeline (Nextflow)',
#          '20.04.1',
#          'https://github.com/ebi-gene-expression-group/scxa-control-workflow'],
#         ['plot_pca',
#          'Scanpy PlotEmbed',
#          '1.4.3+galaxy0',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_plot_embed/882f4671d686'],
#         ['QC',
#          'FastQC',
#          '0.11.8',
#          'http://www.bioinformatics.babraham.ac.uk/projects/fastqc/'],
#         ['Reference',
#          'Ensembl',
#          '99',
#          'Homo_sapiens.GRCh38.cdna.all.99.fa.gz, Homo_sapiens.GRCh38.99.gtf.gz'],
#         ['resolution',
#          'Scanpy ParameterIterator',
#          '0.0.1+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/f0dd61087af3'],
#         ['run_pca',
#          'Scanpy RunPCA',
#          '1.4.3+galaxy10',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_pca/2dd53b944e78'],
#         ['run_tsne',
#          'Scanpy RunTSNE',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_tsne/3589dfaef3f6'],
#         ['run_umap',
#          'Scanpy RunUMAP',
#          '1.4.3+galaxy1',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_umap/c111d7d04f0b'],
#         ['Scanpy Read10x',
#          'Scanpy Read10x',
#          '1.4.3+galaxy0',
#          'https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_read_10x/cf55e0e462da'],
#         ['Configuration',
#          'scxa-workflows',
#          'db1eeaf',
#          'https://github.com/ebi-gene-expression-group/scxa-workflows']]}},
#      {'type': 'resources',
#       'name': 'Resources',
#       'props': {'url': 'json/experiments/E-CURD-10/resources/SUPPLEMENTARY_INFORMATION'}}]}},
#   {'type': 'downloads',
#    'name': 'Downloads',
#    'props': {'data': [{'title': 'Metadata files',
#       'files': [{'url': 'experiment/E-CURD-10/download/zip?fileType=experiment-metadata&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Experiment metadata (SDRF and IDF files archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download?fileType=experiment-design&accessKey=',
#         'type': 'icon-experiment-design',
#         'description': 'Experiment design file (TSV format)',
#         'isDownload': True}]},
#      {'title': 'Result files',
#       'files': [{'url': 'experiment/E-CURD-10/download?fileType=cluster&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Clustering file (TSV format)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=quantification-filtered&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Filtered TPMs files (MatrixMarket archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=marker-genes&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Marker gene files (TSV files archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=normalised&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Normalised counts files (MatrixMarket archive)',
#         'isDownload': True},
#        {'url': 'experiment/E-CURD-10/download/zip?fileType=quantification-raw&accessKey=',
#         'type': 'icon-tsv',
#         'description': 'Raw counts files (MatrixMarket archive)',
#         'isDownload': True}]}]}}]}

# %% [markdown]
# # Convert data to dicts

# %%
specimen_dict, headers, headers_order = get_headers_dict_from_sample(samples[0])
# Out:
# ({'sample_characteristics': {'organism': set(),
#    'age': set(),
#    'developmental stage': set(),
#    'sex': set(),
#    'growth condition': set(),
#    'organism part': set(),
#    'metastatic site': set(),
#    'sampling site': set(),
#    'disease': set(),
#    'clinical history': set(),
#    'single cell quality': set()},
#   'experimental_variables': {'single cell quality': set()}},
#  {'sample_characteristics': ['organism',
#    'age',
#    'developmental stage',
#    'sex',
#    'growth condition',
#    'organism part',
#    'metastatic site',
#    'sampling site',
#    'disease',
#    'clinical history',
#    'single cell quality'],
#   'experimental_variables': ['single cell quality', 'single cell quality']},
#  {'sample_characteristics': 1, 'experimental_variables': 2})

# %%
samples_values = {}
for sample in samples:
    
    sample_id = sample['experimentAccession']
    
    sample_values = sample_to_dict(sample)
    
    samples_values[sample_id] = process_dict(sample_values)
    
with open('../SingleCell-Files/projects_values.json', 'w') as outfile:
    json.dump(samples_values, outfile)

# %%
samples_values = {}
for sample in samples:
    
    sample_id = sample['experimentAccession']
    
    sample_values = sample_to_dict(sample)
    
    if 'individual' not in sample_values['sample_characteristics']:
        samples_values[sample_id] = process_dict(sample_values)
    
with open('../SingleCell-Files/projects_values_without_individual.json', 'w') as outfile:
    json.dump(samples_values, outfile)

# %%
sample_to_dict(samples[0])
# Out:
# {'sample_characteristics': {'organism': {'Homo sapiens'},
#   'age': {'43 year'},
#   'developmental stage': {'adult'},
#   'sex': {'male'},
#   'growth condition': {'biopsy from metastatic neoplasm',
#    'biopsy from primary neoplasm',
#    'patient-derived mouse xenograft from mixed primary and metastatic neoplasm'},
#   'organism part': {'kidney'},
#   'metastatic site': {'lung', 'not applicable'},
#   'sampling site': {'neoplasm'},
#   'disease': {'renal cell carcinoma'},
#   'clinical history': {'tumor refractory to pazopanib, everolimus and high-dose interleukin-2'},
#   'single cell quality': {'OK'}},
#  'experimental_variables': {'single cell quality': {'PDX_mRCC_SC_01',
#    'PDX_mRCC_SC_03',
#    'PDX_mRCC_SC_04',
#    'PDX_mRCC_SC_05',
#    'PDX_mRCC_SC_06',
#    'PDX_mRCC_SC_08',
#    'PDX_mRCC_SC_12',
#    'PDX_mRCC_SC_14',
#    'PDX_mRCC_SC_15',
#    'PDX_mRCC_SC_20',
#    'PDX_mRCC_SC_21',
#    'PDX_mRCC_SC_34',
#    'PDX_mRCC_SC_41',
#    'PDX_mRCC_SC_44',
#    'PDX_mRCC_SC_52',
#    'PDX_mRCC_SC_56',
#    'PDX_mRCC_SC_60',
#    'PDX_mRCC_SC_61',
#    'PDX_mRCC_SC_63',
#    'PDX_mRCC_SC_64',
#    'PDX_mRCC_SC_68',
#    'PDX_mRCC_SC_69',
#    'PDX_mRCC_SC_70',
#    'PDX_mRCC_SC_77',
#    'PDX_mRCC_SC_79',
#    'PDX_mRCC_SC_80',
#    'PDX_mRCC_SC_81',
#    'PDX_mRCC_SC_86',
#    'PDX_mRCC_SC_87',
#    'PDX_mRCC_SC_88',
#    'PDX_mRCC_SC_89',
#    'PDX_mRCC_SC_90',
#    'PDX_mRCC_SC_92',
#    'PDX_mRCC_SC_93',
#    'PDX_mRCC_SC_94',
#    'PDX_mRCC_SC_95',
#    'PDX_pRCC_SC_03',
#    'PDX_pRCC_SC_05',
#    'PDX_pRCC_SC_06',
#    'PDX_pRCC_SC_10',
#    'PDX_pRCC_SC_13',
#    'PDX_pRCC_SC_14',
#    'PDX_pRCC_SC_16',
#    'PDX_pRCC_SC_24',
#    'PDX_pRCC_SC_27',
#    'PDX_pRCC_SC_28',
#    'PDX_pRCC_SC_29',
#    'PDX_pRCC_SC_34',
#    'PDX_pRCC_SC_35',
#    'PDX_pRCC_SC_36',
#    'PDX_pRCC_SC_37',
#    'PDX_pRCC_SC_46',
#    'PDX_pRCC_SC_49',
#    'PDX_pRCC_SC_50',
#    'PDX_pRCC_SC_51',
#    'PDX_pRCC_SC_52',
#    'PDX_pRCC_SC_53',
#    'PDX_pRCC_SC_55',
#    'PDX_pRCC_SC_56',
#    'PDX_pRCC_SC_57',
#    'PDX_pRCC_SC_58',
#    'PDX_pRCC_SC_59',
#    'PDX_pRCC_SC_60',
#    'PDX_pRCC_SC_61',
#    'PDX_pRCC_SC_62',
#    'PDX_pRCC_SC_65',
#    'PDX_pRCC_SC_66',
#    'PDX_pRCC_SC_67',
#    'PDX_pRCC_SC_68',
#    'PDX_pRCC_SC_70',
#    'PDX_pRCC_SC_72',
#    'PDX_pRCC_SC_73',
#    'PDX_pRCC_SC_75',
#    'PDX_pRCC_SC_78',
#    'PDX_pRCC_SC_79',
#    'PDX_pRCC_SC_84',
#    'PDX_pRCC_SC_87',
#    'PDX_pRCC_SC_88',
#    'PDX_pRCC_SC_89',
#    'PDX_pRCC_SC_90',
#    'PDX_pRCC_SC_91',
#    'PDX_pRCC_SC_93',
#    'PDX_pRCC_SC_94',
#    'Pt_mRCC_SC_01',
#    'Pt_mRCC_SC_03',
#    'Pt_mRCC_SC_05',
#    'Pt_mRCC_SC_10',
#    'Pt_mRCC_SC_11',
#    'Pt_mRCC_SC_12',
#    'Pt_mRCC_SC_17',
#    'Pt_mRCC_SC_21',
#    'Pt_mRCC_SC_23',
#    'Pt_mRCC_SC_24',
#    'Pt_mRCC_SC_30',
#    'Pt_mRCC_SC_33',
#    'Pt_mRCC_SC_36',
#    'Pt_mRCC_SC_39',
#    'Pt_mRCC_SC_43',
#    'Pt_mRCC_SC_53',
#    'Pt_mRCC_SC_56',
#    'Pt_mRCC_SC_57',
#    'Pt_mRCC_SC_58',
#    'Pt_mRCC_SC_59',
#    'Pt_mRCC_SC_61',
#    'Pt_mRCC_SC_64',
#    'Pt_mRCC_SC_69',
#    'Pt_mRCC_SC_71',
#    'Pt_mRCC_SC_75',
#    'Pt_mRCC_SC_79',
#    'Pt_mRCC_SC_81',
#    'Pt_mRCC_SC_84',
#    'Pt_mRCC_SC_85',
#    'Pt_mRCC_SC_86',
#    'Pt_mRCC_SC_87',
#    'Pt_mRCC_SC_88',
#    'Pt_mRCC_SC_90',
#    'Pt_mRCC_SC_92',
#    'Pt_mRCC_SC_93',
#    'biopsy from metastatic neoplasm',
#    'biopsy from primary neoplasm',
#    'patient-derived mouse xenograft from mixed primary and metastatic neoplasm'}}}

# %%
'individual' in sample_to_dict(samples[0])['sample_characteristics']
# Out:
# False
