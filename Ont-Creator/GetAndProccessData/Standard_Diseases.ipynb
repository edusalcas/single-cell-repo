# %%
import requests
import pandas as pd
import urllib.parse
import json
import time
import re

from IPython.display import clear_output
from GetTermsOntobee import get_URI_from_name, get_name_from_URI

# %% [markdown]
# # SCEA diseases

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
ontologies = ['PATO', 'MONDO', 'DOID', 'HP']

# %%
def get_terms_from_project(experiment_id, name_column, ontology_column):
    terms = []
    terms_names = []
    
    experiment_metadata = f"https://www.ebi.ac.uk/gxa/sc/experiment/{experiment_id}/download?fileType=experiment-design&accessKey="
    
    df = pd.read_csv(experiment_metadata, sep='\t', low_memory=False)
    
    display(df)
    
    # If project doesnt have the expected column, finish
    if name_column not in df.columns:
        return terms, terms_names
    
    project_term_names = df[name_column].unique()
    project_term_URIs = df[ontology_column].unique()

    print(project_term_names)
    print(project_term_URIs)
    
    # Balance names and URIs
    project_term_URIs = list(project_term_URIs)
    project_term_URIs += [None] * (len(project_term_names) - len(project_term_URIs))

    for name, URI in zip(project_term_names, project_term_URIs):
        # If we have already code the cell_type we skip it
        if name in terms_names:
            continue

        print(name)

        # If we have no info of URI we search for it
        if URI is None or str(URI) == 'nan':
            for ontology in ontologies:

                URI = get_URI_from_name(name, ontology)
                time.sleep(1)

                if URI is not None:
                    terms.append({
                        'name': name,
                        'URI': URI
                    })

            if URI is None:
                URI = get_URI_from_name(name)
                time.sleep(1)

                terms.append({
                    'name': name,
                    'URI': URI
                })

        # Otherwise   
        else:                    
            terms_names.append(name)

            terms.append({
                'name': name,
                'URI': URI
            })

        # If there are two or more cell types in the name
        if URI is None:
            new_l = re.split(' and |, |; ', name)
            for new_name in new_l:

                for ontology in ontologies:

                    URI = get_URI_from_name(new_name, ontology)
                    time.sleep(1)

                    if URI is not None:

                        terms.append({
                            'name': new_name,
                            'URI': URI
                        })

                if URI is None:
                    URI = get_URI_from_name(name)
                    time.sleep(1)

                    terms.append({
                        'name': name,
                        'URI': URI
                    })

                terms_names.append(new_name)


    return terms, terms_names

# %%
diseases = []
disease_names = []
avoid_collections = ["Human Cell Atlas"]

n_experiments = len(answer.json()['experiments'])

for n, experiment in enumerate(answer.json()['experiments']):
    print(f"{n+1}/{n_experiments}")

    if [i for i in experiment["experimentProjects"] if i in avoid_collections]:
        clear_output(wait=True)
        continue
    
    experiment_id = experiment['experimentAccession']
    diseases_pro, disease_names_pro = get_terms_from_project(experiment_id=experiment_id, 
                                                             name_column='Sample Characteristic[disease]', 
                                                             ontology_column='Sample Characteristic Ontology Term[disease]')
    
    diseases += diseases_pro
    disease_names += disease_names_pro
               
    clear_output(wait=True)

df = pd.DataFrame(diseases)
# Out:
# 181/181
# normal
# COVID-19

# %%
df = df.drop_duplicates()

# %%
df[df.isnull().any(axis=1)].name.tolist()
# Out:
# ['bronchioalveolar carcinoma; non-small cell lung cancer']

# %%
df[df['name'] == 'bronchioalveolar carcinoma']
# Out:
#                          name                                           URI
# 2  bronchioalveolar carcinoma  http://purl.obolibrary.org/obo/MONDO_0000503
# 3  bronchioalveolar carcinoma   http://purl.obolibrary.org/obo/DOID_0050870

# %%
from OntologyConversorSCAE import OntologyConversorSCAE

conversor = OntologyConversorSCAE()

# %%
df['name'] = df['name'].apply(conversor.parse_word)
df
# Out:
#                                    name  \
# 0                    RenalCellCarcinoma
# 1             BronchioalveolarCarcinoma
# 2             BronchioalveolarCarcinoma
# 3             BronchioalveolarCarcinoma
# 5                NonSmallCellLungCancer
# 6                NonSmallCellLungCancer
# 7                NonSmallCellLungCancer
# 8                NonSmallCellLungCancer
# 9                         LungCarcinoma
# 10                               Normal
# 12                        CrohnsDisease
# 14                        LungCarcinoma
# 15                             COVID-19
# 17              MyelodysplasticSyndrome
# 18     RefractoryAnemiaWithExcessBlasts
# 19              MyelodysplasticSyndrome
# 23                               Normal
# 26                         Glioblastoma
# 27                             Melanoma
# 28                Type2DiabetesMellitus
# 30                      MultipleMyeloma
# 32                                  HIV
# 36    SmallIntestineNeuroendocrineTumor
# 37    SmallIntestineNeuroendocrineTumor
# 38    SmallIntestineNeuroendocrineTumor
# 40                  CecumAdenocarcinoma
# 41                 RectumAdenocarcinoma
# 42   ChronicObstructivePulmonaryDisease
# 47                  MacularDegeneration
# 48                  MacularDegeneration
# 51     HeadAndNeckSquamousCellCarcinoma
# 54                            Influenza
# 58                ObstructiveSleepApnea
# 60                         BreastCancer
# 61                         BreastCancer
# 63                      MyeloidLeukemia
# 68                Type1DiabetesMellitus
# 70                         Glioblastoma
# 72          IdiopathicPulmonaryFibrosis
# 75                       ProstateCancer
# 77                           HepatitisC
# 84                    MyxoidLiposarcoma
# 86                        LungCarcinoma
# 87                        LungCarcinoma
# 90           AcuteLymphoblasticLeukemia
# 91           AcuteLymphoblasticLeukemia
# 92           AcuteLymphoblasticLeukemia
# 96                        LungCarcinoma
# 98                        NotApplicable
# 104              FetalGrowthRestriction
# 110                            Fibrosis
# 111                            Fibrosis
# 112                            Fibrosis
# 113                            Fibrosis
# 116                    OvarianCarcinoma
# 119                   ParkinsonsDisease
# 124                          Tonsilitis
# 131                    ColorectalCancer
# 132                    PancreaticCancer
# 134                    OvarianCarcinoma
#
#                                                 URI
# 0              http://www.ebi.ac.uk/efo/EFO_0000681
# 1                                              None
# 2      http://purl.obolibrary.org/obo/MONDO_0000503
# 3       http://purl.obolibrary.org/obo/DOID_0050870
# 5              http://www.ebi.ac.uk/efo/EFO_0003060
# 6      http://purl.obolibrary.org/obo/MONDO_0005233
# 7          http://purl.obolibrary.org/obo/DOID_3908
# 8         http://purl.obolibrary.org/obo/HP_0030358
# 9              http://www.ebi.ac.uk/efo/EFO_0000571
# 10      http://purl.obolibrary.org/obo/PATO_0000461
# 12             http://www.ebi.ac.uk/efo/EFO_0000384
# 14             http://www.ebi.ac.uk/efo/EFO_0003060
# 15     http://purl.obolibrary.org/obo/MONDO_0100096
# 17             http://www.ebi.ac.uk/efo/EFO_0000198
# 18             http://www.ebi.ac.uk/efo/EFO_0003811
# 19      http://purl.obolibrary.org/obo/PATO_0000461
# 23         http://purl.obolibrary.org/obo/DOID_1572
# 26             http://www.ebi.ac.uk/efo/EFO_0000519
# 27             http://www.ebi.ac.uk/efo/EFO_0000756
# 28             http://www.ebi.ac.uk/efo/EFO_0001360
# 30             http://www.ebi.ac.uk/efo/EFO_0001378
# 32             http://www.ebi.ac.uk/efo/EFO_0000764
# 36             http://www.ebi.ac.uk/efo/EFO_1001928
# 37     http://purl.obolibrary.org/obo/MONDO_0002995
# 38         http://purl.obolibrary.org/obo/DOID_4434
# 40             http://www.ebi.ac.uk/efo/EFO_1000020
# 41             http://www.ebi.ac.uk/efo/EFO_0005631
# 42             http://www.ebi.ac.uk/efo/EFO_0000341
# 47             http://www.ebi.ac.uk/efo/EFO_0004683
# 48     http://purl.obolibrary.org/obo/MONDO_0005417
# 51             http://www.ebi.ac.uk/efo/EFO_0000181
# 54             http://www.ebi.ac.uk/efo/EFO_0007328
# 58             http://www.ebi.ac.uk/efo/EFO_0003918
# 60      http://purl.obolibrary.org/obo/NCIT_C133501
# 61             http://www.ebi.ac.uk/efo/EFO_0000305
# 63        http://purl.obolibrary.org/obo/NCIT_C3175
# 68             http://www.ebi.ac.uk/efo/EFO_0001359
# 70             http://www.ebi.ac.uk/efo/EFO_0000519
# 72             http://www.ebi.ac.uk/efo/EFO_0000768
# 75             http://www.ebi.ac.uk/efo/EFO_0001663
# 77             http://www.ebi.ac.uk/efo/EFO_0003047
# 84             http://www.ebi.ac.uk/efo/EFO_0000613
# 86             http://www.ebi.ac.uk/efo/EFO_0000708
# 87             http://www.ebi.ac.uk/efo/EFO_0003050
# 90             http://www.ebi.ac.uk/efo/EFO_1001935
# 91     http://purl.obolibrary.org/obo/MONDO_0000814
# 92        http://purl.obolibrary.org/obo/MP_0014050
# 96             http://www.ebi.ac.uk/efo/EFO_0001071
# 98   http://purl.obolibrary.org/obo/GENEPIO_0001619
# 104            http://www.ebi.ac.uk/efo/EFO_0000495
# 110            http://www.ebi.ac.uk/efo/EFO_0006890
# 111    http://purl.obolibrary.org/obo/MONDO_0010912
# 112       http://purl.obolibrary.org/obo/DOID_10353
# 113       http://purl.obolibrary.org/obo/HP_0030760
# 116            http://www.ebi.ac.uk/efo/EFO_0002917
# 119            http://www.ebi.ac.uk/efo/EFO_0002508
# 124    http://purl.obolibrary.org/obo/MONDO_0001039
# 131            http://www.ebi.ac.uk/efo/EFO_0005842
# 132            http://www.ebi.ac.uk/efo/EFO_0003860
# 134            http://www.ebi.ac.uk/efo/EFO_0001075

# %% [markdown]
# # HCA diseases

# %%
seed_url = "https://service.azul.data.humancellatlas.org/index/projects?size=999&catalog=dcp1"

# %%
# User-Agent obtenido del recurso del curso.
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)
project_hits = answer.json()["hits"]

# %%
projects = []
accessing_error = []

n_projects = len(project_hits)

diseases = []

for n, hit in enumerate(project_hits):    
    for item in hit['donorOrganisms']:
        diseases += item['disease']
        
    clear_output(wait=True)
    
diseases = list(set(diseases))

# %%
diseases = [x for x in diseases if x is not None]
diseases
# Out:
# ['arthritis',
#  'irritable bowel syndrome',
#  'melanoma (disease)',
#  'asymptomatic dengue',
#  'hemolytic-uremic syndrome',
#  'hereditary hemochromatosis',
#  'ventricular tachycardia',
#  'prostate cancer',
#  'depressive disorder',
#  'pure autonomic failure',
#  'acoustic neuroma',
#  'hyperlipidemia (disease)',
#  'obstructive sleep apnea syndrome',
#  'reversible cerebral vasoconstriction syndrome',
#  'essential hypertension',
#  'cardiac arrest',
#  'gastroesophageal reflux disease',
#  'benign prostatic hyperplasia (disease)',
#  'acquired aneurysmal subarachnoid hemorrhage',
#  'hiatus hernia (disease)',
#  'adrenal cortex adenoma',
#  'kidney cancer',
#  'pericardial effusion (disease)',
#  'colitis (disease)',
#  'anxiety disorder',
#  'osteoarthritis, hip',
#  'Enterococcus faecalis infection',
#  'ulcerative colitis (disease)',
#  'cataract (disease)',
#  'hypertension',
#  'type 2 diabetes mellitus',
#  'orofaciodigital syndrome VIII',
#  'stroke disorder',
#  'diverticulitis',
#  'syndromic dyslipidemia',
#  'end stage renal failure',
#  'acute kidney tubular necrosis',
#  'Lyme disease',
#  'non-alcoholic fatty liver disease',
#  'normal']

# %%
diseases_URIs = list(map(get_URI_from_name, diseases))
diseases_URIs
# Out:
# ['http://purl.obolibrary.org/obo/MONDO_0001549',
#  'http://purl.obolibrary.org/obo/MONDO_0005101',
#  'http://purl.obolibrary.org/obo/MONDO_0010336',
#  'http://purl.obolibrary.org/obo/MONDO_0004375',
#  'http://purl.obolibrary.org/obo/MONDO_0005292',
#  'http://purl.obolibrary.org/obo/MONDO_0005148',
#  'http://purl.obolibrary.org/obo/MPATH_458']

# %%
from OntologyConversorHCA import OntologyConversorHCA

conversor = OntologyConversorHCA()

# %%
diseases = list(map(conversor.parse_word, diseases))
diseases
# Out:
# ['HemolyticUremicSyndrome',
#  'UlcerativeColitis',
#  'OrofaciodigitalSyndromeVIII',
#  'EndStageRenalFailure',
#  'UlcerativeColitis',
#  'Type2DiabetesMellitus',
#  'Control']

# %%
rows = pd.DataFrame({'name': diseases, 'URI': diseases_URIs})
rows
# Out:
#                           name                                           URI
# 0      HemolyticUremicSyndrome  http://purl.obolibrary.org/obo/MONDO_0001549
# 1            UlcerativeColitis  http://purl.obolibrary.org/obo/MONDO_0005101
# 2  OrofaciodigitalSyndromeVIII  http://purl.obolibrary.org/obo/MONDO_0010336
# 3         EndStageRenalFailure  http://purl.obolibrary.org/obo/MONDO_0004375
# 4            UlcerativeColitis  http://purl.obolibrary.org/obo/MONDO_0005292
# 5        Type2DiabetesMellitus  http://purl.obolibrary.org/obo/MONDO_0005148
# 6                      Control      http://purl.obolibrary.org/obo/MPATH_458

# %%
df = df.append(rows, ignore_index=True).drop_duplicates()
df
# Out:
#                            name                                           URI
# 0            RenalCellCarcinoma          http://www.ebi.ac.uk/efo/EFO_0000681
# 1     BronchioalveolarCarcinoma                                          None
# 2     BronchioalveolarCarcinoma  http://purl.obolibrary.org/obo/MONDO_0000503
# 3     BronchioalveolarCarcinoma   http://purl.obolibrary.org/obo/DOID_0050870
# 4        NonSmallCellLungCancer          http://www.ebi.ac.uk/efo/EFO_0003060
# ..                          ...                                           ...
# 62  OrofaciodigitalSyndromeVIII  http://purl.obolibrary.org/obo/MONDO_0010336
# 63         EndStageRenalFailure  http://purl.obolibrary.org/obo/MONDO_0004375
# 64            UlcerativeColitis  http://purl.obolibrary.org/obo/MONDO_0005292
# 65        Type2DiabetesMellitus  http://purl.obolibrary.org/obo/MONDO_0005148
# 66                      Control      http://purl.obolibrary.org/obo/MPATH_458
#
# [66 rows x 2 columns]

# %%
df.to_csv('../SingleCell-Files/diseases_ontology.csv', index=False, header=False, sep='\t')

# %% [markdown]
# # Tests

# %%
diseases_pro, disease_names_pro = get_terms_from_project(experiment_id='E-CURD-55', 
                                                         name_column='Sample Characteristic[disease]', 
                                                         ontology_column='Sample Characteristic Ontology Term[disease]')
# Out:
#                              Assay Sample Characteristic[organism]  \
# 0      SAMC150711-AAAAACGACGCTCTTC                    Homo sapiens
# 1      SAMC150711-AAAACGACGCTCTTCC                    Homo sapiens
# 2      SAMC150711-AAACAAGACGCTCTTC                    Homo sapiens
# 3      SAMC150711-AAACACGACGCTCTTC                    Homo sapiens
# 4      SAMC150711-AAACCTGCAAATTGCC                    Homo sapiens
# ...                            ...                             ...
# 97583  SAMC191986-TTTGTCATCAAACCGT                    Homo sapiens
# 97584  SAMC191986-TTTGTCATCCAATGGT                    Homo sapiens
# 97585  SAMC191986-TTTGTCATCCTTTCGG                    Homo sapiens
# 97586  SAMC191986-TTTGTCATCGTCGTTC                    Homo sapiens
# 97587  SAMC191986-TTTGTCATCTTCAACT                    Homo sapiens
#
#        Sample Characteristic Ontology Term[organism]  \
# 0      http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1      http://purl.obolibrary.org/obo/NCBITaxon_9606
# 2      http://purl.obolibrary.org/obo/NCBITaxon_9606
# 3      http://purl.obolibrary.org/obo/NCBITaxon_9606
# 4      http://purl.obolibrary.org/obo/NCBITaxon_9606
# ...                                              ...
# 97583  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 97584  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 97585  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 97586  http://purl.obolibrary.org/obo/NCBITaxon_9606
# 97587  http://purl.obolibrary.org/obo/NCBITaxon_9606
#
#       Sample Characteristic[developmental stage]  \
# 0                                          adult
# 1                                          adult
# 2                                          adult
# 3                                          adult
# 4                                          adult
# ...                                          ...
# 97583                                      adult
# 97584                                      adult
# 97585                                      adult
# 97586                                      adult
# 97587                                      adult
#
#       Sample Characteristic Ontology Term[developmental stage]  \
# 0                   http://www.ebi.ac.uk/efo/EFO_0001272
# 1                   http://www.ebi.ac.uk/efo/EFO_0001272
# 2                   http://www.ebi.ac.uk/efo/EFO_0001272
# 3                   http://www.ebi.ac.uk/efo/EFO_0001272
# 4                   http://www.ebi.ac.uk/efo/EFO_0001272
# ...                                                  ...
# 97583               http://www.ebi.ac.uk/efo/EFO_0001272
# 97584               http://www.ebi.ac.uk/efo/EFO_0001272
# 97585               http://www.ebi.ac.uk/efo/EFO_0001272
# 97586               http://www.ebi.ac.uk/efo/EFO_0001272
# 97587               http://www.ebi.ac.uk/efo/EFO_0001272
#
#       Sample Characteristic[individual]  \
# 0                                  ERS1
# 1                                  ERS1
# 2                                  ERS1
# 3                                  ERS1
# 4                                  ERS1
# ...                                 ...
# 97583                 Healthy_Control_2
# 97584                 Healthy_Control_2
# 97585                 Healthy_Control_2
# 97586                 Healthy_Control_2
# 97587                 Healthy_Control_2
#
#        Sample Characteristic Ontology Term[individual]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 97583                                              NaN
# 97584                                              NaN
# 97585                                              NaN
# 97586                                              NaN
# 97587                                              NaN
#
#       Sample Characteristic[disease]  \
# 0                           COVID-19
# 1                           COVID-19
# 2                           COVID-19
# 3                           COVID-19
# 4                           COVID-19
# ...                              ...
# 97583                         normal
# 97584                         normal
# 97585                         normal
# 97586                         normal
# 97587                         normal
#
#        Sample Characteristic Ontology Term[disease]  \
# 0      http://purl.obolibrary.org/obo/MONDO_0100096
# 1      http://purl.obolibrary.org/obo/MONDO_0100096
# 2      http://purl.obolibrary.org/obo/MONDO_0100096
# 3      http://purl.obolibrary.org/obo/MONDO_0100096
# 4      http://purl.obolibrary.org/obo/MONDO_0100096
# ...                                             ...
# 97583   http://purl.obolibrary.org/obo/PATO_0000461
# 97584   http://purl.obolibrary.org/obo/PATO_0000461
# 97585   http://purl.obolibrary.org/obo/PATO_0000461
# 97586   http://purl.obolibrary.org/obo/PATO_0000461
# 97587   http://purl.obolibrary.org/obo/PATO_0000461
#
#       Sample Characteristic[disease staging]  \
# 0                       early recovery stage
# 1                       early recovery stage
# 2                       early recovery stage
# 3                       early recovery stage
# 4                       early recovery stage
# ...                                      ...
# 97583                        healthy control
# 97584                        healthy control
# 97585                        healthy control
# 97586                        healthy control
# 97587                        healthy control
#
#       Sample Characteristic Ontology Term[disease staging]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 97583        http://purl.obolibrary.org/obo/PATO_0000461
# 97584        http://purl.obolibrary.org/obo/PATO_0000461
# 97585        http://purl.obolibrary.org/obo/PATO_0000461
# 97586        http://purl.obolibrary.org/obo/PATO_0000461
# 97587        http://purl.obolibrary.org/obo/PATO_0000461
#
#               Sample Characteristic[sampling time point]  \
# 0      less than 7 days after negative nucleic acid b...
# 1      less than 7 days after negative nucleic acid b...
# 2      less than 7 days after negative nucleic acid b...
# 3      less than 7 days after negative nucleic acid b...
# 4      less than 7 days after negative nucleic acid b...
# ...                                                  ...
# 97583                                                NaN
# 97584                                                NaN
# 97585                                                NaN
# 97586                                                NaN
# 97587                                                NaN
#
#        Sample Characteristic Ontology Term[sampling time point]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 97583                                                NaN
# 97584                                                NaN
# 97585                                                NaN
# 97586                                                NaN
# 97587                                                NaN
#
#       Sample Characteristic[organism part]  \
# 0                                    blood
# 1                                    blood
# 2                                    blood
# 3                                    blood
# 4                                    blood
# ...                                    ...
# 97583                                blood
# 97584                                blood
# 97585                                blood
# 97586                                blood
# 97587                                blood
#
#       Sample Characteristic Ontology Term[organism part]  \
# 0          http://purl.obolibrary.org/obo/UBERON_0000178
# 1          http://purl.obolibrary.org/obo/UBERON_0000178
# 2          http://purl.obolibrary.org/obo/UBERON_0000178
# 3          http://purl.obolibrary.org/obo/UBERON_0000178
# 4          http://purl.obolibrary.org/obo/UBERON_0000178
# ...                                                  ...
# 97583      http://purl.obolibrary.org/obo/UBERON_0000178
# 97584      http://purl.obolibrary.org/obo/UBERON_0000178
# 97585      http://purl.obolibrary.org/obo/UBERON_0000178
# 97586      http://purl.obolibrary.org/obo/UBERON_0000178
# 97587      http://purl.obolibrary.org/obo/UBERON_0000178
#
#       Factor Value[disease]           Factor Value Ontology Term[disease]  \
# 0                  COVID-19  http://purl.obolibrary.org/obo/MONDO_0100096
# 1                  COVID-19  http://purl.obolibrary.org/obo/MONDO_0100096
# 2                  COVID-19  http://purl.obolibrary.org/obo/MONDO_0100096
# 3                  COVID-19  http://purl.obolibrary.org/obo/MONDO_0100096
# 4                  COVID-19  http://purl.obolibrary.org/obo/MONDO_0100096
# ...                     ...                                           ...
# 97583                normal   http://purl.obolibrary.org/obo/PATO_0000461
# 97584                normal   http://purl.obolibrary.org/obo/PATO_0000461
# 97585                normal   http://purl.obolibrary.org/obo/PATO_0000461
# 97586                normal   http://purl.obolibrary.org/obo/PATO_0000461
# 97587                normal   http://purl.obolibrary.org/obo/PATO_0000461
#
#       Factor Value[disease staging]  \
# 0              early recovery stage
# 1              early recovery stage
# 2              early recovery stage
# 3              early recovery stage
# 4              early recovery stage
# ...                             ...
# 97583               healthy control
# 97584               healthy control
# 97585               healthy control
# 97586               healthy control
# 97587               healthy control
#
#        Factor Value Ontology Term[disease staging]
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 97583  http://purl.obolibrary.org/obo/PATO_0000461
# 97584  http://purl.obolibrary.org/obo/PATO_0000461
# 97585  http://purl.obolibrary.org/obo/PATO_0000461
# 97586  http://purl.obolibrary.org/obo/PATO_0000461
# 97587  http://purl.obolibrary.org/obo/PATO_0000461
#
# [97588 rows x 19 columns]
# ['COVID-19' 'normal']
# ['http://purl.obolibrary.org/obo/MONDO_0100096'
#  'http://purl.obolibrary.org/obo/PATO_0000461']
# COVID-19
# normal

# %%
disease_names_pro
# Out:
# ['COVID-19', 'normal']
