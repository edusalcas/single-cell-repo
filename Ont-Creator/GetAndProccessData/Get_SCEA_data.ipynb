# %% [markdown]
# # Obtain Projects and specimens from Single Cell Expression Atlas

# %% [markdown]
# ## Imports

# %%
import requests
import json
import re
import time
import numpy as np
import pandas as pd

from pprint import pprint
from lxml import html
from IPython.display import clear_output

# %% [markdown]
# ## Get the projects and save them

# %%
def get_info_from_html(experiment_ID):
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"
  
    # Get the project samples information
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        return None
    
    # Parse response so we get the sample information
    parser = html.fromstring(answer.text)
    script_text = parser.xpath(".//div[@id='content']//script[3]/text()") 
    match = re.search(r'content: (?P<value>{.*})', script_text[0])
    value = match.group('value')
    
    return json.loads(value)

# %%
def get_headers_dict_from_sample(sample):
    headers_aux = {
        'sample_characteristics': {},
        'experimental_variables': {}
    }

    header_order = {}
    header_types = {
        'sample_characteristics': [],
        'experimental_variables': []        
    }

    # Init dictionary and the header types for the sample
    sample_headers = sample['tabs'][1]['props']['table']['headers']
    sample_characteristics_headers = []
    experimental_variables_headers = []

    for n, sample_header in enumerate(sample_headers):
        if sample_header['name'] == 'Sample Characteristics':
            header_order['sample_characteristics'] = n
            for sample_characteristic in sample_header['values']:
                # If key has not been viewed yet, add it to dictionary
                if sample_characteristic not in headers_aux['sample_characteristics'].keys():
                    headers_aux['sample_characteristics'][sample_characteristic] = set()

                # Add the type of the header
                header_types['sample_characteristics'] += [sample_characteristic]
        elif sample_header['name'] == 'Experimental Variables':
            header_order['experimental_variables'] = n
            for experimental_variable in sample_header['values']:
                # If key has not been viewed yet, add it to dictionary
                if sample_characteristic not in headers_aux['experimental_variables'].keys():
                    headers_aux['experimental_variables'][sample_characteristic] = set()

                # Add the types of the header
                header_types['experimental_variables'] += [sample_characteristic]
                
    return headers_aux, header_types, header_order

# %%
def sample_to_dict(sample):
    # Get headers, initiating dict, headers types and the order of the headers
    dictionary, header_types, header_order = get_headers_dict_from_sample(sample)
    
    # Get sample data
    sample_data = sample['tabs'][1]['props']['table']['data']

    # For each cell in data
    for cell in sample_data:
        # For each header type
        for header_type in ['sample_characteristics', 'experimental_variables']:
            # Add the values to the dictionary
            values = cell['values'][header_order[header_type]]
            headers = header_types[header_type]
            for value, header_name in zip(values, headers):
                dictionary[header_type][header_name].add(value)
        
    return dictionary

# %%
def process_dict(dictionary):
    for key in dictionary:
        for key2 in dictionary[key]:
            dictionary[key][key2] = list(dictionary[key][key2])
    return dictionary

# %%
seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments"

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
answer = requests.get(seed_url, headers=headers)

# %%
accessing_error = []
projects = []
n_experiments = len(answer.json()["experiments"])

avoid_collections = ["Human Cell Atlas"]

for n, experiment in enumerate(answer.json()['experiments']):
    experiment_ID = experiment['experimentAccession']
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/results/tsne"
    
    # Print loop information
    print("Getting project \"" + experiment_ID + "\"")
    print("Number of errors: " + str(len(accessing_error)))
    print(f"{n+1}/{n_experiments}")
    
    # If the projects is in a repository we already have we skip it
    if [i for i in experiment["experimentProjects"] if i in avoid_collections]:
        clear_output(wait=True)
        continue
    
    # Wait between request so we dont overcharge server
    time.sleep(2.0)
    
    # Get the project samples information
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        continue
        
    # Parse response so we get the useful information
    parser = html.fromstring(answer.text)
    publication_link = parser.xpath(".//a[@class='pubmed-id']/@href")
    publication_title = parser.xpath(".//a[@class='pubmed-id']/text()")

    experiment['publication_link'] = publication_link
    experiment['publication_title'] = publication_title
    experiment['repository_link'] = seed_url
    experiment['supplementary_link'] = []
    
    # Get supplementary information
    seed_url = "https://www.ebi.ac.uk/gxa/sc/json/experiments/" + experiment_ID + "/resources/SUPPLEMENTARY_INFORMATION"
    ## Wait between request so we dont overcharge server
    time.sleep(2.0)
    
    answer = requests.get(seed_url, headers=headers)
    
    # If couldn't get the information save the error
    if answer.status_code != requests.codes.ok:
        accessing_error.append(answer)
        clear_output(wait=True)
        continue
    
    answer_json = answer.json()
    experiment['ENA_ID'] = None
    experiment['ArrayExpress_ID'] = None

    # For each repository information, save the id and the url of the project
    for group in answer.json():
        if group['type'] == 'icon-ena': # If ENA repository
            ena_id_re = re.search('([SE]RP\d+)', group['description'])
            
            if not ena_id_re:
                continue
            
            ena_id = ena_id_re.group(1)
            
            experiment['ENA_ID'] = ena_id
            experiment['supplementary_link'].append(group['url'])
            
        elif group['type'] == 'icon-ae': # If Array Expression repository
            ae_id_re = re.search('(E-MTAB-\d+)', group['description'])
            
            if not ae_id_re:
                continue
            
            ae_id = ae_id_re.group(1)
            
            experiment['ArrayExpress_ID'] = ae_id
            experiment['supplementary_link'].append(group['url'])
            
        else:
            continue
    
    # Get download information
    time.sleep(2.0)
   
    exp_info = get_info_from_html(experiment_ID)
    
    experiment['downloads'] = exp_info['tabs'][3]['props']['data']
    
    # Experiment design
    
    exp_info_headers = exp_info['tabs'][1]['props']['table']['headers']
    column_names = exp_info_headers[0]['values'] + \
                   exp_info_headers[1]['values'] + \
                   exp_info_headers[2]['values']

    # Read tsv with experiment design data
    df = pd.read_csv(
        "https://www.ebi.ac.uk/gxa/sc/experiment/" + experiment_ID + "/download?fileType=experiment-design&accessKey=",
        sep="\t",
        low_memory=False)

    # Delete Ontology terms columns
    cols = [c for c in df.columns if 'ontology term' not in c.lower()]
    df = df[cols]

    # Rename columns
    df.columns = column_names
    df = df.loc[:, ~df.columns.duplicated()]  # Drop duplicated columns

    # Remove assay column from df
    assay = df.Assay
    df = df.drop('Assay', axis=1)

    # Remove duplicated rows
    df = df.drop_duplicates()

    if 'single cell identifier' in column_names:
        column_names.remove('single cell identifier')
        df = df.drop('single cell identifier', axis=1)
    
    sample_type = get_sample_type(df)
    experiment['sample_type'] = sample_type
    
    experiment['project_info'] = {}
    for column in df:
        experiment['project_info'][column] = list(df[column].unique().astype(str))
    
    if 'individual' in column_names:
        experiment['donors'] = len(experiment['project_info']['individual'])
    else:
        experiment['donors'] = -1
    
    # Add the project to the list
    projects.append(experiment)
    
    clear_output(wait=True)
# Out:
# Getting project "E-MTAB-9221"
# Number of errors: 0
# 181/181

# %%
print(len(projects))
# Out:
# 159

# %%
def convert(o):
    if isinstance(o, np.int64): return int(o)  
    raise TypeError

# %%
with open('../../SingleCell-Files/raw_data/SCAE_projects.json', 'w') as outfile:
    json.dump({"experiments": projects}, outfile)

# %% [markdown]
# # Get the specimens and save them

# %%
with open('../SingleCell-Files/raw_data/SCAE_projects.json') as f:
    projects = json.load(f)['experiments']

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
}

# %%
# https://www.ebi.ac.uk/gxa/sc/experiments/*NOMBRE EXPERIMENTO*/experiment-design
experiment_ID = projects[100]['experimentAccession']
seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"

# %%
answer = requests.get(seed_url, headers=headers)

# %%
parser = html.fromstring(answer.text)

# %%
script_text = parser.xpath(".//div[@id='content']//script[3]/text()")

# %%
print(answer.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <title>Experiment < Single Cell Expression Atlas &lt; EMBL-EBI</title>
#     <meta name="description" content="EMBL-EBI Single Cell Expression Atlas, an open public repository of single cell gene expression data">
#     <meta name="keywords" content="expression atlas, single cell expression, gene expression, baseline expression, functional genomics, public repository, repository, bioinformatics, europe, institute">
#     <meta name="author" content="EBI Gene Expression Team – https://www.ebi.ac.uk/about/people/irene-papatheodorou">
#     <meta name="HandheldFriendly" content="true" />
#     <meta name="MobileOptimized" content="width" />
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <meta name="theme-color" content="#70BDBD"> <!-- Android Chrome mobile browser tab color -->
#
#     <!-- Add information on the life cycle of this page -->
#     <meta name="ebi:owner" content="Irene Papatheodorou <irenep@ebi.ac.uk>">
#     <meta name="ebi:review-cycle" content="60">
#     <meta name="ebi:last-review" content="2018-05-01">
#     <meta name="ebi:expiry" content="2018-07-01">
#
#     <!-- If you link to any other sites frequently, consider optimising performance with a DNS prefetch -->
#     <link rel="dns-prefetch" href="https://www.ebi.ac.uk/gxa/">
#     <link rel="dns-prefetch" href="https://www.ebi.ac.uk/arrayexpress/">
#     <link rel="dns-prefetch" href="https://www.ebi.ac.uk/">
#     <link rel="dns-prefetch" href="https://embl.de/">
#
#     <!-- If you have custom icon, replace these as appropriate. You can generate them at realfavicongenerator.net -->
#     <link rel="icon" type="image/x-icon" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/favicon.ico" />
#     <link rel="icon" type="image/png" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/favicon-32x32.png" />
#     <link rel="icon" type="image/png" sizes="192×192" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/android-chrome-192x192.png" /> <!-- Android (192px) -->
#     <link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-114x114.png" /> <!-- For iPhone 4 Retina display (114px) -->
#     <link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-72x72.png" /> <!-- For iPad (72px) -->
#     <link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-144x144.png" /> <!-- For iPad retina (144px) -->
#     <link rel="apple-touch-icon-precomposed" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/apple-icon-57x57.png" /> <!-- For iPhone (57px) -->
#     <link rel="mask-icon" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/safari-pinned-tab.svg" color="#ffffff" /> <!-- Safari icon for pinned tab -->
#     <meta name="msapplication-TileColor" content="#2b5797" /> <!-- MS Icons -->
#     <meta name="msapplication-TileImage" content="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/images/logos/EMBL-EBI/favicons/mstile-144x144.png" />
#
#     <!-- CSS: implied media=all -->
#     <!-- CSS concatenated and minified via ant build script-->
#     <link rel="stylesheet" href="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/css/ebi-global.css" type="text/css" media="all" />
#     <link rel="stylesheet" href="https://ebi.emblstatic.net/web_guidelines/EBI-Icon-fonts/v1.3/fonts.css" type="text/css" media="all" />
#
#     <!-- If you have a custom header image or colour -->
#     <meta name="ebi:masthead-color" content="rgb(0,124,130)" />
#     <meta name="ebi:masthead-image" content="/gxa/sc/resources/images/cells_background.png" />
#
#     <!-- you can replace this with theme-[projectname].css. See http://www.ebi.ac.uk/web/style/colour for details of how to do this -->
#     <!-- also inform ES so we can host your colour palette file -->
#     <!-- <link rel="stylesheet" href="https://dev.ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/css/theme-embl-petrol.css" type="text/css" media="all" /> -->
#     <link rel="stylesheet" href="/gxa/sc/resources/css/theme-atlas.css" type="text/css" media="all">
#
#     <!-- Use this CSS file for any custom styling -->
#     <link rel="stylesheet" href="/gxa/sc/resources/css/atlas.css" type="text/css" media="all">
#     <!-- end CSS-->
# </head>
#
# <body>
# <div id="skip-to">
#     <ul>
#         <li><a href="#content">Skip to main content</a></li>
#         <li><a href="#local-nav">Skip to local navigation</a></li>
#         <li><a href="#global-nav">Skip to EBI global navigation menu</a></li>
#         <li><a href="#global-nav-expanded">Skip to expanded EBI global navigation menu (includes all sub-sections)</a></li>
#     </ul>
# </div>
#
#
#
# <header id="masthead-black-bar" class="clearfix masthead-black-bar">
# </header>
#
# <script>
#   // Hack that solves https://github.com/ebiwd/EBI-Framework/pull/139 (I got tired of waiting)
#   window.addEventListener('load', function(event) {
#     $('#masthead-black-bar nav')[2].className='row expanded';
#   });
# </script>
#
#
#
# <div data-sticky-container>
#     <header id="masthead" class="masthead" data-sticky data-sticky-on="large" data-top-anchor="content:top" data-btm-anchor="content:bottom">
#         <div class="masthead-inner row expanded">
#             <div class="small-12 large-8 columns">
#                 <!-- local-title -->
#                 <a href="/gxa/sc/home" title="Back to Single Cell Expression Atlas homepage">
#                     <div class="media-object" id="local-title">
#                         <div class="media-object-section hide-for-small-only">
#                             <img src="/gxa/sc/resources/images/logos/sc_atlas_logo.png" alt="Single Cell Expression Atlas logo" style="height:7em">
#                         </div>
#                         <div class="media-object-section">
#                             <h1>Single&nbsp;Cell Expression&nbsp;Atlas</h1>
#                             <h4 class="show-for-large">Single cell gene expression across species</h4>
#                         </div>
#                     </div>
#                 </a>
#             </div>
#             <div class="small-12 large-4 columns">
#                 <div class="media-object" style="display: flex; justify-content: flex-end; align-items: center;">
#                     <div class="media-object-section">
#                         <h4 class="show-for-large">Query bulk expression</h4>
#                         <a href="/gxa" title="To Expression Atlas" class="button" style="box-shadow: 2px 2px 2px 2px rgba(0,0,0,0.5)"><i class="icon icon-functional" data-icon="<"></i> Back to Expression Atlas</a>
#                     </div>
#                     <div class="media-object-section show-for-large">
#                         <a href="https://wellcome.ac.uk/">
#                             <img src="/gxa/sc/resources/images/logos/wellcome_trust_logo_black.png" alt="Wellcome Trust logo" style="max-height: 5.5em; background: white">
#                         </a>
#                     </div>
#                 </div>
#             </div>
#
#             <nav>
#                 <ul id="local-nav" class="dropdown menu float-left" data-description="navigational">
#                     <li id="local-nav-home"><a href="/gxa/sc/home"><i class="icon icon-generic padding-right-medium" data-icon="H"></i>Home</a></li>
#                     <li id="local-nav-search"><a href="/gxa/sc/search"><i class="icon icon-functional padding-right-medium" data-icon="1"></i>Gene search</a></li>
#                     <li id="local-nav-experiments"><a href="/gxa/sc/experiments"><i class="icon icon-functional padding-right-medium" data-icon="C"></i>Browse experiments</a></li>
#
#                     <li id="local-nav-release-notes"><a href="/gxa/sc/release-notes.html"><i class="icon icon-generic padding-right-medium" data-icon=";"></i>Release notes</a></li>
#                     <li id="local-nav-help"><a href="/gxa/sc/help.html"><i class="icon icon-generic padding-right-medium" data-icon="?"></i>Help</a></li>
#
#                     <li id="local-nav-feedback"><a href="https://www.ebi.ac.uk/support/gxasc" target="_blank" data-icon="X"><i class="icon icon-generic padding-right-medium" data-icon="s"></i>Support</a></li>
#                 </ul>
#             </nav>
#             <!-- /local-nav -->
#         </div>
#     </header>
# </div>
#
#
# <div id="content">
#     <div id="main-content-area" class="margin-top-large margin-bottom-large" role="main">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="experimentDescription" class="row column expanded">
#     <div class="media-object stack-for-small">
#
#
#         <div class="media-object-section middle">
#             <h3 id="goto-experiment">
#                 Immune cell profiling of COVID-19 patients in the recovery stage by single-cell sequencing
#             </h3>
#
#             <h5>Single-cell RNA-Seq mRNA baseline</h5>
#             <div>Number of cells: 97,587</div>
#
#             <div id="experimentOrganisms">Organism:
#                 <span style="font-style:italic">Homo sapiens</span>
#             </div>
#
#
#             <div id="experimentReferences">
#
#
#                         Publication:
#
#
#
#
#                 <ul>
#
#                     <li>
#
#                         <span>Zheng Y, Liu X, Le W, Xie L, Li H et al. (2020)</span>
#
#                         <i>
#
#
#                                 <a class="pubmed-id"
#                                    href="https://europepmc.org/abstract/MED/32780218"
#                                    title="Read publication"
#                                    target='_blank'>A human circulating immune cell landscape in aging and COVID-19.</a>
#
#
#
#                         </i>
#                     </li>
#
#                 </ul>
#             </div>
#
#
#
#
#
#         </div>
#     </div>
# </div>
#
#
# <div class="row column margin-top-large expanded">
#     <div id="experiment-page"></div>
# </div>
#
# <div id="feedback-button"></div>
#
# <link rel="stylesheet" href="/gxa/sc/resources/css/react-popup.css" type="text/css" media="all">
# <script defer src="/gxa/sc/resources/js-bundles/feedbackForm.bundle.js"></script>
#
# <script defer src="/gxa/sc/resources/js-bundles/experimentPage.bundle.js"></script>
#
# <script>
#   document.addEventListener("DOMContentLoaded", function(event) {
#     experimentPage.render({
#       atlasUrl: '/gxa/sc/',
#       resourcesUrl: '/gxa/sc/resources/js-bundles/',
#       content: {"experimentAccession":"E-CURD-55","accessKey":"","species":"homo sapiens","disclaimer":"","tabs":[{"type":"results","name":"Results","props":{"ks":[7,12,17,21,26,38,50,61,72],"ksWithMarkerGenes":[7,12,17,21,26,38,50,61,72],"selectedK":26,"perplexities":[10,35,1,25,45,5,30,15,50,40,20],"metadata":[{"value":"individual","label":"Individual"},{"value":"disease","label":"Disease"},{"value":"disease_staging","label":"Disease staging"}],"units":["CPM"],"suggesterEndpoint":"json/suggestions"}},{"type":"experiment-design","name":"Experiment Design","props":{"table":{"headers":[{"name":"","values":["Assay"]},{"name":"Sample Characteristics","values":["organism","developmental stage","individual","disease","disease staging","sampling time point","organism part"]},{"name":"Experimental Variables","values":["disease","disease staging"]}],"data":[{"properties":{"analysed":true},"values":[["SAMC150711-AAAAACGACGCTCTTC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAACGACGCTCTTCC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACAAGACGCTCTTC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACACGACGCTCTTC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGCAAATTGCC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGCACCGATAT"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGGTTGGAGGT"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGTCACTTACT"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGACGCTCTTCCG"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGAGACTTGAA"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGAGGATATAC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGAGGTGTGGT"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["COVID-19","early recovery stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGCAAGTTGTC"],["Homo sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days after negative nucleic acid blood test","blood"],["CO ...
#     }, 'experiment-page');
#     feedbackForm.render({
#       feedbackFormLink: 'https://www.ebi.ac.uk/support/gxasc',
#       gaId: 'UA-37676851-3'
#     }, 'feedback-button');
#   });
# </script>
#
#     </div>
# </div>
#
#
#
# <footer id="local-footer" class="local-footer" role="local-footer">
#     <div id="relationships" class="row">
#         <!-- https://www.ebi.ac.uk/style-lab/websites/patterns/banner-elixir.html -->
#         <div class="small-10 columns">
#             <div id="elixir-banner"
#                  data-color="none"
#                  data-use-cdr-logo="false"
#                  data-name="This service"
#                  data-description="Expression Atlas is an ELIXIR database service"
#                  data-more-information-link="https://www.elixir-europe.org/about-us/who-we-are/nodes/embl-ebi"
#                  data-use-basic-styles="false">
#             </div>
#         </div>
#         <div class="small-2 columns text-right padding-top-medium">
#             <a href="https://wellcome.ac.uk/" class="clear">
#                 <img src="/gxa/sc/resources/images/logos/wellcome_trust_logo_black.png"
#                      alt="Wellcome Trust logo" style="height: 4em">
#             </a>
#         </div>
#     </div>
# </footer>
#
# <script defer="defer" src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/js/elixirBanner.js"></script>
#
#
#
# <footer>
#     <div id="global-footer" class="global-footer">
#         <nav id="global-nav-expanded" class="global-nav row">
#         </nav>
#         <section id="ebi-footer-meta" class="ebi-footer-meta row">
#         </section>
#     </div>
# </footer>
#
#
# <!-- Custom JavaScript -->
# <!-- Don’t defer or async, these two need to be loaded before other bundles, which are effectively deferred -->
# <script src="/gxa/sc/resources/js/lib/babel-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js/lib/fetch-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js/lib/url-search-params-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js/lib/append-polyfill.min.js"></script>
# <script src="/gxa/sc/resources/js-bundles/vendorCommons.bundle.js"></script>
#
# <!-- JavaScript -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
# <script defer="defer" src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/js/script.js"></script>
#
# <!-- The Foundation theme JavaScript -->
# <script src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/libraries/foundation-6/js/foundation.js"></script>
# <script src="https://ebi.emblstatic.net/web_guidelines/EBI-Framework/v1.3/js/foundationExtendEBI.js"></script>
# <script type="text/JavaScript">$(document).foundation();</script>
# <script type="text/JavaScript">$(document).foundationExtendEBI();</script>
#
# <!-- Google Analytics -->
# <script>
#   window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#   ga('create', 'UA-37676851-3', 'auto');
#   ga('send', 'pageview');
# </script>
# <script async src="https://www.google-analytics.com/analytics.js"></script>
# <!-- End Google Analytics -->
#
# </body>
# </html>

# %%
match = re.search(r'content: (?P<value>{.*})', script_text[0])

pprint(match.group('value'))
# Out:
# ('{"experimentAccession":"E-CURD-55","accessKey":"","species":"homo '
#  'sapiens","disclaimer":"","tabs":[{"type":"results","name":"Results","props":{"ks":[7,12,17,21,26,38,50,61,72],"ksWithMarkerGenes":[7,12,17,21,26,38,50,61,72],"selectedK":26,"perplexities":[10,35,1,25,45,5,30,15,50,40,20],"metadata":[{"value":"individual","label":"Individual"},{"value":"disease","label":"Disease"},{"value":"disease_staging","label":"Disease '
#  'staging"}],"units":["CPM"],"suggesterEndpoint":"json/suggestions"}},{"type":"experiment-design","name":"Experiment '
#  'Design","props":{"table":{"headers":[{"name":"","values":["Assay"]},{"name":"Sample '
#  'Characteristics","values":["organism","developmental '
#  'stage","individual","disease","disease staging","sampling time '
#  'point","organism part"]},{"name":"Experimental '
#  'Variables","values":["disease","disease '
#  'staging"]}],"data":[{"properties":{"analysed":true},"values":[["SAMC150711-AAAAACGACGCTCTTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAACGACGCTCTTCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACAAGACGCTCTTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACACGACGCTCTTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGCAAATTGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGCACCGATAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGGTTGGAGGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACCTGTCACTTACT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGACGCTCTTCCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGAGACTTGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGAGGATATAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGAGGTGTGGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGCAAGTTGTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGCAGCTGGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGCATCGATGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGCATGAAGTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAACGGGGTCCATCCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGAGATAGTCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGAGGGTGTGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGCAATGACCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGCAGCTTAAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGCATAAAGGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGGTCCGTCAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGGTGAGGGTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGGTTTGCATG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGTCAAGAAGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGATGTCTTGAGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAAAGCCGGTAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAAAGCTGATAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAAAGGAGTTTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAACAACGCACC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAACAGTCAGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAACATCGACGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAAGTACGCTGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAAGTAGGCATG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAAGTCTTGATG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGCAATCTACTATC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGACGACGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGACGCACA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGCAGCCTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGGACAGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGGGCACTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGTAATCCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGAGTGACTCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGCAGAGTGTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGGTAAGTTCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGGTTATCGGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGGTTGCGCAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGTCACAACGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGTCACGGTTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGTCGGCGGTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAAGTAGTCGTCCAGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCAGGAATCGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCCACAACGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCCACAGCGTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCCAGTAAGAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCCATGTAGTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCGTACCGGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCGTCACCTAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCGTCTTTCAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCGTGCTTCTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCGTTGGTTTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCTCCCGACTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAATGCCTCGCATGAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGACGCTCTTCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTAGGACAGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTCATTAGCCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTGTCATATCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTGTGACGGTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTGTTCAACCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTGTTCGCGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACACGTTCCCTTGCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGAGCAAATCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGAGGCCATAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGAGTACGATA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGAGTACGCCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGCAAGCGTAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGCACCTCGTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGCACGGTAGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGCAGCCAGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGGTAAATGTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGGTTTGTTGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGTCGCACTCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCATGTCGTCGTTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGAGGGATCTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGAGTACATGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGCAAGGGTCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGCATGCATGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGCATGTTGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGGTCATATCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGGTCATATGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGGTGATGATA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGGTTATGCGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGGTTCCACAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACCGCGTCAGCTTAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGACGCTCTTCCGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGGTACAGTGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGTCAACACCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGTCAGAGCTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGTCGGAATCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGTCGTCACGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGTCTCGCATC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACGTTGTCTTCAACT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGAGACAGGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGAGATGTCGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGAGGACCACA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGCAACTGCTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGGTCCGCTGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGGTCCGTGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGGTCTCTTTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCAGTCTTGAGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCAGAGCCTAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCAGCAGGTCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCAGCGATTCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCAGTCGAGTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCAGTGGACGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCAGTTGTCGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCCATCACGAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCCATCGGAAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCCATTGCGGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCGTTACAGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCTCACTCTTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCTCATCTGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCCCTCGAATGGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCTTCAACGATCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCTTGTCCGTTAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCTTGTTAGTGGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCTTTCAGCGACC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCTTTCGAATGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTCTTTCTCGATGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTAGAACAACT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTAGTGAATTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTCAACGATCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTCACATAACC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTCATAGTAAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTTCGGTGTTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTGGTTCTCGTATT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCAGCTTTGGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCAGGCTCTTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCAGTCGTACT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCAGTGCTGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCCACACGCTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCCAGCCAATT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCCAGTATGCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCGTATATCCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCGTCACCCAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCGTCGGCATC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCGTGCACCAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCTCAACACCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCTCAGTGTTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCTCAGTTCGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCTCATCGCTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AACTTTCTCCTAGAAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTAGAGCAATT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTAGCACGCCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTAGCCCAACC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTCAAGCTGAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTCAATGTTGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTCAGTACACT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTCATTCCTCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTAAGAGGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTAATAGCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTAGTAGTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTCAAAGCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTCCTAGCG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTGGTCCGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTTTGCATG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGACCTGTTTGTTGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCAGTGGTATCAAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCAGCAATATG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCAGGAGCGTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCAGTGGTAGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCAGTGTTGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCCACATCCGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCCAGCTGCAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCCAGGTGCCT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCGTAATAGCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCGTAGAAAGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCGTATAGTAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCGTCGACTGC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCGTTCCATGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCTCAACGGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGCCGCTCGTGGGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-AAGGAGCAGAGTCTGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
# ...
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGCAAGTCTAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGCAGACAAAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGGTAGCGCAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGGTCGCGGTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGGTGATAAAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGTCAGGCCCA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGTCATTATCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGTCCAGAAGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGTCCGCAGTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAAGAGTCGGGAGTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATACACGACGCTCTTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCAGATCCTGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCAGATGCGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCAGGCCCTTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCCAATGCCAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCCACATGTGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCCAGTCAGCC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCCATCTGGTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCGTCAAAGAT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCGTCAACATC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATAGACCTCATGTGGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCACGAAGTTAACGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCACGAGTAATCACC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCACGAGTCACCCAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTAGACTTGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTAGTCCATAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTCACTTACGA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTCAGATAATG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTCAGGTCGTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTCATCGGAAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTCATGTCCTC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTGTAAATGAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTGTCCGTCAG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTGTCTAGTGT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATCTTCTGCCCTA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATGGAGGATGGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATGGCAATCAGAA"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATGGCATTACCTT"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATGGGTGCGAAAC"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATGGGTTCCACGG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]},{"properties":{"analysed":true},"values":[["SAMC150711-ATCATGGGTTTGACTG"],["Homo '
#  'sapiens","adult","ERS1","COVID-19","early recovery stage","less than 7 days '
#  'after negative nucleic acid blood test","blood"],["COVID-19","early recovery '
#  'stage"]]}]},"downloadUrl":"experiment/E-CURD-55/download?fileType\\u003dexperiment-design\\u0026accessKey\\u003d"}},{"type":"supplementary-information","name":"Supplementary '
#  'Information","props":{"sections":[{"type":"static-table","name":"Analysis '
#  'Methods","props":{"data":[["Analysis","Software","Version","Citation"],["Barcode '
#  'detection and whitelisting, read mapping, UMI deduplication, Gene/transcript '
#  'quantification","Alevin","1.2.0","Srivastava A, Malik L, Smith T, Sudbery I, '
#  'Patro R. Alevin efficiently estimates accurate gene abundances from '
#  'dscRNA-seq data. Genome Biol. 2019;20(1):65."],["Build List","Build '
#  'List","1.0.0",""],["clusering_slotnames","Replace '
#  'Text","1.1.2","https://toolshed.g2.bx.psu.edu/view/bgruening/text_processing/0a8c6b61f0f4"],["Emtpy '
#  'droplet filtering","DropletUtils","1.4.2","Lun ATL, Riesenfeld S, Andrews T, '
#  'et al. EmptyDrops: distinguishing cells from empty droplets in droplet-based '
#  'single-cell RNA sequencing data. Genome Biol. '
#  '2019;20(1):63."],["filter_cells","Scanpy '
#  'FilterCells","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_cells/cf3fb754ddde"],["Filtered '
#  'cellgroup markers","Filter failed","1.0.0",""],["filter_genes","Scanpy '
#  'FilterGenes","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_filter_genes/bac969abf1c6"],["find_clusters","Scanpy '
#  'FindCluster","1.6.0+galaxy3","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_cluster/15e8a4c60418"],["find_markers","Scanpy '
#  'FindMarkers","1.6.0+galaxy3","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_markers/f04dd4e5b6a7"],["find_variable_genes","Scanpy '
#  'FindVariableGenes","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_find_variable_genes/f952b39f0794"],["GTF2GeneList","GTF2GeneList","1.42.1+galaxy4","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/gtf2gene_list/b6354c917ef9"],["harmony_batch","Scanpy '
#  'Harmony","1.6.0+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_integrate_harmony/f1298838e93b"],["make_project_file","AnnData '
#  'Operations","1.6.0+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/anndata_ops/c09d61ede252"],["merged_embeddings","Merge '
#  'Collections","1.0.0",""],["meta_vars","Scanpy '
#  'ParameterIterator","0.0.1+galaxy3","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/ae4debc68f4a"],["neighbours '
#  'for umap","Scanpy '
#  'ComputeGraph","1.6.0+galaxy3","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_compute_graph/3cf0177ed87e"],["n_neighbors","Scanpy '
#  'ParameterIterator","0.0.1+galaxy2","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/7c4d44c14ceb"],["normalise_data","Scanpy '
#  'NormaliseData","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_normalise_data/6aa97861fdfd"],["perplexity","Scanpy '
#  'ParameterIterator","0.0.1+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_parameter_iterator/f0dd61087af3"],["Pipeline","Gene '
#  'expression group single-cell analysis pipeline '
#  '(Nextflow)","20.04.1","https://github.com/ebi-gene-expression-group/scxa-control-workflow"],["plot_pca","Scanpy '
#  'PlotEmbed","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_plot_embed/f48cfaa2e515"],["Reference","Ensembl","99","Homo_sapiens.GRCh38.cdna.all.99.fa.gz, '
#  'Homo_sapiens.GRCh38.99.gtf.gz"],["run_pca","Scanpy '
#  'RunPCA","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_pca/3e7ede8e1c94"],["run_tsne","Scanpy '
#  'RunTSNE","1.6.0+galaxy2","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_tsne/9d2b6c6f9e07"],["run_umap","Scanpy '
#  'RunUMAP","1.6.0+galaxy1","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_run_umap/135e8cacb57e"],["Scanpy '
#  'Read10x","Scanpy '
#  'Read10x","1.6.0+galaxy0","https://toolshed.g2.bx.psu.edu/view/ebi-gxa/scanpy_read_10x/5ff50f4a26cd"],["Configuration","scxa-workflows","9c04ada","https://github.com/ebi-gene-expression-group/scxa-workflows"]]}},{"type":"resources","name":"Resources","props":{"url":"json/experiments/E-CURD-55/resources/SUPPLEMENTARY_INFORMATION"}}]}},{"type":"downloads","name":"Downloads","props":{"data":[{"title":"Metadata '
#  'files","files":[{"url":"experiment/E-CURD-55/download/zip?fileType\\u003dexperiment-metadata\\u0026accessKey\\u003d","type":"icon-tsv","description":"Experiment '
#  'metadata (SDRF and IDF files '
#  'archive)","isDownload":true},{"url":"experiment/E-CURD-55/download?fileType\\u003dexperiment-design\\u0026accessKey\\u003d","type":"icon-experiment-design","description":"Experiment '
#  'design file (TSV format)","isDownload":true}]},{"title":"Result '
#  'files","files":[{"url":"experiment/E-CURD-55/download?fileType\\u003dcluster\\u0026accessKey\\u003d","type":"icon-tsv","description":"Clustering '
#  'file (TSV '
#  'format)","isDownload":true},{"url":"experiment/E-CURD-55/download/zip?fileType\\u003dmarker-genes\\u0026accessKey\\u003d","type":"icon-tsv","description":"Marker '
#  'gene files (TSV files '
#  'archive)","isDownload":true},{"url":"experiment/E-CURD-55/download/zip?fileType\\u003dnormalised\\u0026accessKey\\u003d","type":"icon-tsv","description":"Normalised '
#  'counts files (MatrixMarket '
#  'archive)","isDownload":true},{"url":"experiment/E-CURD-55/download/zip?fileType\\u003dquantification-raw\\u0026accessKey\\u003d","type":"icon-tsv","description":"Raw '
#  'counts files (MatrixMarket archive)","isDownload":true}]}]}}]}')

# %%
specimens = []
accessing_error = []

for n, experiment in enumerate(projects):
    # Get the ID of the proyect and make the url
    experiment_ID = experiment['experimentAccession']
    seed_url = "https://www.ebi.ac.uk/gxa/sc/experiments/" + experiment_ID + "/experiment-design"
  
    # Print loop information
    print("Getting specimens from experiment \"" + experiment_ID + "\"")
    print("Number of errors: " + str(len(accessing_error)))
    print(f"{n+1}/{len(projects)}")
    
    # Wait between request so we dont overcharge server
    time.sleep(2.0)

    # Get specimens info
    experiment_specimens = get_specimens(experiment_ID)
    for item in experiment_specimens:
        item.update({
            "project_title": experiment['experimentDescription'],
            "experiment_projects": experiment['experimentProjects']
        })   
    # Add the samples to the list
    specimens += experiment_specimens
    
    clear_output(wait=True)
# Out:
# Getting specimens from experiment "E-MTAB-9221"
# Number of errors: 0
# 159/159

# %%
specimens_json = {'specimens': specimens}

# %%
with open('../../SingleCell-Files/raw_data/SCAE_samples.json', 'w') as outfile:
    json.dump(specimens_json, outfile, default=convert)

# %% [markdown]
# # Tests

# %%
import requests
import json
import re
import time
import pandas as pd

from pprint import pprint
from lxml import html
from IPython.display import clear_output

# %%
def get_gb_columns(columns):
    gb_columns = []
    
    if 'individual' in columns:
        gb_columns += ['individual']
    elif 'disease' in columns:
        gb_columns += ['disease']
    elif 'strain' in columns:
        gb_columns += ['strain']
    elif 'cell line' in columns:
        gb_columns += ['cell line']

    if 'organism part' in columns:
        gb_columns += ['organism part']

    if 'sampling site' in columns:
        gb_columns += ['sampling site']
    elif 'metastatic site' in columns:
        gb_columns += ['metastatic site']
        
    if 'growth condition' in columns:
        gb_columns += ['growth condition']
    
    if 'stimulus' in columns:
        gb_columns += ['stimulus']
        
    return gb_columns

# %%
def get_sample_type(dataframe):
    sample_type = []
    
    columns = dataframe.columns
    
    # Cell line
    if 'cell line' in columns:
        sample_type += ['CellLines']
        
    # Organoid
    if 'growth condition' in columns:
        # print(list(dataframe['growth condition']))
        aux = [s for s in list(dataframe['growth condition']) if 'organoid' in str(s)]
        if aux:
            sample_type += ['Organoids']
    elif 'individual' in columns:
        # print(list(dataframe['individual']))
        aux = [s for s in list(dataframe['individual']) if 'organoid' in str(s)]
        if aux:
            sample_type += ['Organoids']
    elif 'organism part' in columns:
        # print(list(dataframe['organism part']))
        aux = [s for s in list(dataframe['organism part']) if 'organoid' in str(s)]
        if aux:
            sample_type += ['Organoids']
    
    # Specimen
    if not sample_type:
        sample_type = ['Specimens']
    
    return sample_type

# %%
def get_specimens(project_id):
    headers = {
        "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36"
    }
    exp_info = get_info_from_html(project_id)
    
    exp_info_headers = exp_info['tabs'][1]['props']['table']['headers']
    column_names = exp_info_headers[0]['values'] +\
                   exp_info_headers[1]['values'] +\
                   exp_info_headers[2]['values']
    
    # Get columns for the group by
    gb_columns = get_gb_columns(column_names)
    # Read tsv with experiment design data
    df = pd.read_csv("https://www.ebi.ac.uk/gxa/sc/experiment/" + project_id + "/download?fileType=experiment-design&accessKey=", sep="\t", low_memory=False)
        
    # Delete Ontology terms columns
    cols = [c for c in df.columns if 'ontology term' not in c.lower()]
    df = df[cols]
    # Rename columns
    df.columns = column_names
    df = df.loc[:,~df.columns.duplicated()] # Drop duplicated columns

    if 'single cell identifier' in column_names:
        column_names.remove('single cell identifier')
        df = df.drop('single cell identifier', axis=1)

    specimens = []
    # Group columns by individual and organ
    if gb_columns:
        df_gb = df.groupby(by=gb_columns)
        
        # For each group (specimen) get the data
        for name, group in df_gb:
            assay = group.Assay
            group = group.drop('Assay', axis=1)
            group = group.drop_duplicates()

            sample_type = get_sample_type(group)
            
            specimen = {
                'project_id': project_id,
                'cells': list(assay),
                'num_cells': len(list(assay)),
                'sample_type': sample_type,
                'specimen_info': {}
            }
            for column in group:
                specimen['specimen_info'][column] = list(group[column].unique())

            specimens.append(specimen)
    # If there is no column to group by
    else:
        assay = df.Assay
        df = df.drop('Assay', axis=1)
        df = df.drop_duplicates()
        
        sample_type = get_sample_type(df)

        specimen = {
            'project_id': project_id,
            'cells': list(assay),
            'num_cells': len(list(assay)),
            'sample_type': sample_type,
            'specimen_info': {}
        }
        for column in df:
            specimen['specimen_info'][column] = list(df[column].unique().astype(str))

        specimens.append(specimen)
    
    return specimens

# %%
get_specimens('E-CURD-11')
# Out:
# [{'project_id': 'E-CURD-11',
#   'cells': ['SRR2049340',
#    'SRR2049341',
#    'SRR2049342',
#    'SRR2049343',
#    'SRR2049344',
#    'SRR2049345',
#    'SRR2049346',
#    'SRR2049347',
#    'SRR2049348',
#    'SRR2049349',
#    'SRR2049350',
#    'SRR2049351',
#    'SRR2049352',
#    'SRR2049353',
#    'SRR2049354',
#    'SRR2049355',
#    'SRR2049356',
#    'SRR2049357',
#    'SRR2049358',
#    'SRR2049359',
#    'SRR2049360',
#    'SRR2049361',
#    'SRR2049362',
#    'SRR2049363',
#    'SRR2049364',
#    'SRR2049365',
#    'SRR2049366',
#    'SRR2049367',
#    'SRR2049368',
#    'SRR2049369',
#    'SRR2049370',
#    'SRR2049371',
#    'SRR2049372',
#    'SRR2049373',
#    'SRR2049374',
#    'SRR2049375',
#    'SRR2049376',
#    'SRR2049377',
#    'SRR2049378',
#    'SRR2049379',
#    'SRR2049380',
#    'SRR2049381',
#    'SRR2049382',
#    'SRR2049383',
#    'SRR2049384',
#    'SRR2049385',
#    'SRR2049386',
#    'SRR2049387',
#    'SRR2049388',
#    'SRR2049389'],
#   'num_cells': 50,
#   'sample_type': ['CellLines'],
#   'specimen_info': {'organism': ['Homo sapiens'],
#    'individual': ['H358'],
#    'age': ['not applicable'],
#    'sex': ['male'],
#    'developmental stage': ['not available'],
#    'organism part': ['bronchiole'],
#    'metastatic site': ['alveolus of lung'],
#    'disease': ['bronchioalveolar carcinoma; non-small cell lung cancer'],
#    'growth condition': ['in vivo culture'],
#    'cell type': ['epithelial cell'],
#    'cell line': ['H358'],
#    'clinical history': ['not applicable'],
#    'single cell quality': ['OK']}},
#  {'project_id': 'E-CURD-11',
#   'cells': ['SRR2049487',
#    'SRR2049488',
#    'SRR2049489',
#    'SRR2049490',
#    'SRR2049491',
#    'SRR2049492',
#    'SRR2049493',
#    'SRR2049494',
#    'SRR2049495',
#    'SRR2049496',
#    'SRR2049497',
#    'SRR2049498',
#    'SRR2049499',
#    'SRR2049500',
#    'SRR2049501',
#    'SRR2049502',
#    'SRR2049503',
#    'SRR2049504',
#    'SRR2049505',
#    'SRR2049506',
#    'SRR2049507',
#    'SRR2049508',
#    'SRR2049509',
#    'SRR2049510',
#    'SRR2049511',
#    'SRR2049512',
#    'SRR2049513',
#    'SRR2049514',
#    'SRR2049515',
#    'SRR2049516',
#    'SRR2049517',
#    'SRR2049518',
#    'SRR2049519',
#    'SRR2049520',
#    'SRR2049521',
#    'SRR2049522',
#    'SRR2049523',
#    'SRR2049524',
#    'SRR2049525',
#    'SRR2049526',
#    'SRR2049527',
#    'SRR2049528',
#    'SRR2049529',
#    'SRR2049530',
#    'SRR2049531',
#    'SRR2049532',
#    'SRR2049533',
#    'SRR2049534',
#    'SRR2049535'],
#   'num_cells': 49,
#   'sample_type': ['CellLines'],
#   'specimen_info': {'organism': ['Homo sapiens'],
#    'individual': ['LC-MBT-15'],
#    'age': ['57 year'],
#    'sex': ['female'],
#    'developmental stage': ['adult'],
#    'organism part': ['lung'],
#    'metastatic site': ['brain'],
#    'disease': ['lung adenocarcinoma'],
#    'growth condition': ['patient derived mouse xenograft'],
#    'cell type': ['not applicable'],
#    'cell line': ['not applicable'],
#    'clinical history': ['post chemotherapy and erlotinib'],
#    'single cell quality': ['OK']}},
#  {'project_id': 'E-CURD-11',
#   'cells': ['SRR2049396',
#    'SRR2049397',
#    'SRR2049398',
#    'SRR2049399',
#    'SRR2049400',
#    'SRR2049401',
#    'SRR2049402',
#    'SRR2049403',
#    'SRR2049404',
#    'SRR2049405',
#    'SRR2049406',
#    'SRR2049407',
#    'SRR2049408',
#    'SRR2049409',
#    'SRR2049410',
#    'SRR2049411',
#    'SRR2049412',
#    'SRR2049413',
#    'SRR2049414',
#    'SRR2049415',
#    'SRR2049416',
#    'SRR2049417',
#    'SRR2049418',
#    'SRR2049419',
#    'SRR2049420',
#    'SRR2049421',
#    'SRR2049422',
#    'SRR2049423',
#    'SRR2049424',
#    'SRR2049425',
#    'SRR2049426',
#    'SRR2049427',
#    'SRR2049428',
#    'SRR2049429',
#    'SRR2049437',
#    'SRR2049438',
#    'SRR2049439',
#    'SRR2049440',
#    'SRR2049441',
#    'SRR2049442',
#    'SRR2049443',
#    'SRR2049444',
#    'SRR2049445',
#    'SRR2049446',
#    'SRR2049447',
#    'SRR2049448',
#    'SRR2049449',
#    'SRR2049450',
#    'SRR2049451',
#    'SRR2049452',
#    'SRR2049453',
#    'SRR2049454',
#    'SRR2049455',
#    'SRR2049456',
#    'SRR2049457',
#    'SRR2049458',
#    'SRR2049459',
#    'SRR2049460',
#    'SRR2049461',
#    'SRR2049462',
#    'SRR2049463',
#    'SRR2049464',
#    'SRR2049465',
#    'SRR2049466',
#    'SRR2049467',
#    'SRR2049468',
#    'SRR2049469',
#    'SRR2049470',
#    'SRR2049471',
#    'SRR2049472',
#    'SRR2049473',
#    'SRR2049474',
#    'SRR2049475',
#    'SRR2049476',
#    'SRR2049477',
#    'SRR2049478',
#    'SRR2049479'],
#   'num_cells': 77,
#   'sample_type': ['CellLines'],
#   'specimen_info': {'organism': ['Homo sapiens'],
#    'individual': ['LC-PT-45'],
#    'age': ['60 year'],
#    'sex': ['male'],
#    'developmental stage': ['adult'],
#    'organism part': ['middle lobe of right lung'],
#    'metastatic site': ['not applicable'],
#    'disease': ['lung adenocarcinoma'],
#    'growth condition': ['patient derived mouse xenograft'],
#    'cell type': ['not applicable'],
#    'cell line': ['not applicable'],
#    'clinical history': ['treatment naive'],
#    'single cell quality': ['OK']}}]
